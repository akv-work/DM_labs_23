# %%
# !pip install ucimlrepo
# !pip install tensorflow
# !pip install scikit-learn

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, f1_score
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from ucimlrepo import fetch_ucirepo
import warnings
warnings.filterwarnings('ignore')

print("TensorFlow version:", tf.__version__)
# Out:
# Collecting ucimlrepo
#   Downloading ucimlrepo-0.0.7-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ucimlrepo) (2.2.2)
# Requirement already satisfied: certifi>=2020.12.5 in /usr/local/lib/python3.12/dist-packages (from ucimlrepo) (2025.10.5)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->ucimlrepo) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->ucimlrepo) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->ucimlrepo) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->ucimlrepo) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.17.0)
# Downloading ucimlrepo-0.0.7-py3-none-any.whl (8.0 kB)
# Installing collected packages: ucimlrepo
# Successfully installed ucimlrepo-0.0.7
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.10.5)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.10)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# TensorFlow version: 2.19.0

# %%
print("ЗАГРУЗКА ДАТАСЕТА CARDIOTOCOGRAPHY")
print("="*50)

cardiotocography = fetch_ucirepo(id=193)

X = cardiotocography.data.features
y = cardiotocography.data.targets

print("Информация о датасете Cardiotocography:")
print(f"Размерность признаков (X): {X.shape}")
print(f"Размерность целевой переменной (y): {y.shape}")

print("\nНазвания признаков:")
print(X.columns.tolist())

print("\nНазвания целевых переменных:")
print(y.columns.tolist())

print("\nУникальные значения в CLASS/NSP:")
print(y['NSP'].value_counts().sort_index())
# Out:
# ЗАГРУЗКА ДАТАСЕТА CARDIOTOCOGRAPHY
# ==================================================
# Информация о датасете Cardiotocography:
# Размерность признаков (X): (2126, 21)
# Размерность целевой переменной (y): (2126, 2)
#
# Названия признаков:
# ['LB', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV', 'MLTV', 'Width', 'Min', 'Max', 'Nmax', 'Nzeros', 'Mode', 'Mean', 'Median', 'Variance', 'Tendency']
#
# Названия целевых переменных:
# ['CLASS', 'NSP']
#
# Уникальные значения в CLASS/NSP:
# NSP
# 1    1655
# 2     295
# 3     176
# Name: count, dtype: int64

# %%
print("ПРЕДОБРАБОТКА ДАННЫХ")
print("="*50)

print(f"Пропущенные значения в X: {X.isnull().sum().sum()}")
print(f"Пропущенные значения в y: {y.isnull().sum().sum()}")

if X.isnull().sum().sum() > 0:
    print("Заполняем пропущенные значения...")
    X = X.fillna(X.mean())

y_target = y['NSP'].values

y_target = y_target - 1

print(f"\nРаспределение классов в целевой переменной (после преобразования):")
class_distribution = pd.Series(y_target).value_counts().sort_index()
print(class_distribution)

class_names = {
    0: 'Normal',
    1: 'Suspect',
    2: 'Pathologic'
}

print("\nСоответствие классов:")
for class_id, class_name in class_names.items():
    count = class_distribution.get(class_id, 0)
    print(f"Класс {class_id} ({class_name}): {count} примеров")

plt.figure(figsize=(10, 6))
plt.bar(class_names.values(), class_distribution.values, color=['green', 'orange', 'red'])
plt.title('Распределение классов в датасете Cardiotocography')
plt.ylabel('Количество примеров')
plt.xlabel('Класс')
plt.grid(True, alpha=0.3)
plt.show()

X_train, X_test, y_train, y_test = train_test_split(
    X, y_target, test_size=0.2, random_state=42, stratify=y_target
)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

print(f"\nРазмер train выборки: {X_train_scaled.shape}")
print(f"Размер test выборки: {X_test_scaled.shape}")
print(f"Количество классов: {len(np.unique(y_target))}")
print(f"Количество признаков: {X_train_scaled.shape[1]}")
# Out:
# ПРЕДОБРАБОТКА ДАННЫХ
# ==================================================
# Пропущенные значения в X: 0
# Пропущенные значения в y: 0
#
# Распределение классов в целевой переменной (после преобразования):
# 0    1655
# 1     295
# 2     176
# Name: count, dtype: int64
#
# Соответствие классов:
# Класс 0 (Normal): 1655 примеров
# Класс 1 (Suspect): 295 примеров
# Класс 2 (Pathologic): 176 примеров
# Размер train выборки: (1700, 21)
# Размер test выборки: (426, 21)
# Количество классов: 3
# Количество признаков: 21

# %%
print("БАЗОВАЯ МОДЕЛЬ (без предобучения)")
print("="*50)

def create_base_model(input_dim, num_classes):
    model = models.Sequential([
        layers.Dense(128, activation='relu', input_shape=(input_dim,)),
        layers.Dropout(0.3),
        layers.Dense(64, activation='relu'),
        layers.Dropout(0.3),
        layers.Dense(32, activation='relu'),
        layers.Dropout(0.2),
        layers.Dense(num_classes, activation='softmax')
    ])
    return model

input_dim = X_train_scaled.shape[1]
num_classes = len(np.unique(y_target))

base_model = create_base_model(input_dim, num_classes)
base_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

print("Архитектура базовой модели:")
base_model.summary()

# Обучение базовой модели
history_base = base_model.fit(
    X_train_scaled, y_train,
    epochs=100,
    batch_size=32,
    validation_split=0.2,
    verbose=1,
    callbacks=[
        keras.callbacks.EarlyStopping(patience=15, restore_best_weights=True),
        keras.callbacks.ReduceLROnPlateau(patience=10, factor=0.5)
    ]
)

test_loss_base, test_accuracy_base = base_model.evaluate(X_test_scaled, y_test, verbose=0)
print(f"\nБазовая модель - Test Accuracy: {test_accuracy_base:.4f}")
# Out:
# БАЗОВАЯ МОДЕЛЬ (без предобучения)
# ==================================================
# Архитектура базовой модели:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │         2,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 3)              │            99 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,251 (51.76 KB)
#  Trainable params: 13,251 (51.76 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 15s 140ms/step - accuracy: 0.5611 - loss: 0.9524 - val_accuracy: 0.8353 - val_loss: 0.4875 - learning_rate: 0.0010
# Epoch 2/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8134 - loss: 0.5302 - val_accuracy: 0.8794 - val_loss: 0.3303 - learning_rate: 0.0010
# Epoch 3/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8559 - loss: 0.3778 - val_accuracy: 0.8941 - val_loss: 0.2831 - learning_rate: 0.0010
# Epoch 4/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8511 - loss: 0.3760 - val_accuracy: 0.8912 - val_loss: 0.2571 - learning_rate: 0.0010
# Epoch 5/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8824 - loss: 0.3107 - val_accuracy: 0.9000 - val_loss: 0.2467 - learning_rate: 0.0010
# Epoch 6/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8837 - loss: 0.2934 - val_accuracy: 0.8912 - val_loss: 0.2292 - learning_rate: 0.0010
# Epoch 7/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8594 - loss: 0.3229 - val_accuracy: 0.9029 - val_loss: 0.2160 - learning_rate: 0.0010
# Epoch 8/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8895 - loss: 0.2815 - val_accuracy: 0.9029 - val_loss: 0.2049 - learning_rate: 0.0010
# Epoch 9/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8877 - loss: 0.2581 - val_accuracy: 0.8971 - val_loss: 0.2013 - learning_rate: 0.0010
# Epoch 10/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9071 - loss: 0.2308 - val_accuracy: 0.9088 - val_loss: 0.1990 - learning_rate: 0.0010
# Epoch 11/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8817 - loss: 0.2824 - val_accuracy: 0.9118 - val_loss: 0.2153 - learning_rate: 0.0010
# Epoch 12/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9009 - loss: 0.2387 - val_accuracy: 0.8971 - val_loss: 0.1935 - learning_rate: 0.0010
# Epoch 13/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9033 - loss: 0.2380 - val_accuracy: 0.9059 - val_loss: 0.1816 - learning_rate: 0.0010
# Epoch 14/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9040 - loss: 0.2264 - val_accuracy: 0.9324 - val_loss: 0.1739 - learning_rate: 0.0010
# Epoch 15/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8931 - loss: 0.2346 - val_accuracy: 0.9176 - val_loss: 0.1768 - learning_rate: 0.0010
# Epoch 16/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9104 - loss: 0.2280 - val_accuracy: 0.9147 - val_loss: 0.1679 - learning_rate: 0.0010
# Epoch 17/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9025 - loss: 0.2137 - val_accuracy: 0.9088 - val_loss: 0.1759 - learning_rate: 0.0010
# Epoch 18/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9105 - loss: 0.2083 - val_accuracy: 0.9206 - val_loss: 0.1710 - learning_rate: 0.0010
# Epoch 19/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9017 - loss: 0.2226 - val_accuracy: 0.9206 - val_loss: 0.1690 - learning_rate: 0.0010
# Epoch 20/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9080 - loss: 0.2072 - val_accuracy: 0.9235 - val_loss: 0.1648 - learning_rate: 0.0010
# Epoch 21/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9110 - loss: 0.2269 - val_accuracy: 0.9118 - val_loss: 0.1640 - learning_rate: 0.0010
# Epoch 22/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9234 - loss: 0.1709 - val_accuracy: 0.9324 - val_loss: 0.1457 - learning_rate: 0.0010
# Epoch 23/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9056 - loss: 0.1912 - val_accuracy: 0.9118 - val_loss: 0.1647 - learning_rate: 0.0010
# Epoch 24/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9096 - loss: 0.2071 - val_accuracy: 0.9088 - val_loss: 0.1709 - learning_rate: 0.0010
# Epoch 25/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9140 - loss: 0.1799 - val_accuracy: 0.9235 - val_loss: 0.1600 - learning_rate: 0.0010
# Epoch 26/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9273 - loss: 0.1722 - val_accuracy: 0.9294 - val_loss: 0.1565 - learning_rate: 0.0010
# Epoch 27/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9270 - loss: 0.1773 - val_accuracy: 0.9206 - val_loss: 0.1528 - learning_rate: 0.0010
# Epoch 28/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9170 - loss: 0.1682 - val_accuracy: 0.9265 - val_loss: 0.1570 - learning_rate: 0.0010
# Epoch 29/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9085 - loss: 0.1987 - val_accuracy: 0.9235 - val_loss: 0.1586 - learning_rate: 0.0010
# Epoch 30/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9281 - loss: 0.1752 - val_accuracy: 0.9235 - val_loss: 0.1669 - learning_rate: 0.0010
# Epoch 31/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9327 - loss: 0.1611 - val_accuracy: 0.9265 - val_loss: 0.1555 - learning_rate: 0.0010
# Epoch 32/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9209 - loss: 0.1736 - val_accuracy: 0.9382 - val_loss: 0.1443 - learning_rate: 0.0010
# Epoch 33/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9322 - loss: 0.1641 - val_accuracy: 0.9235 - val_loss: 0.1616 - learning_rate: 0.0010
# Epoch 34/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9276 - loss: 0.1581 - val_accuracy: 0.9353 - val_loss: 0.1577 - learning_rate: 0.0010
# Epoch 35/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9285 - loss: 0.1554 - val_accuracy: 0.9324 - val_loss: 0.1566 - learning_rate: 0.0010
# Epoch 36/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9362 - loss: 0.1451 - val_accuracy: 0.9265 - val_loss: 0.1602 - learning_rate: 0.0010
# Epoch 37/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9409 - loss: 0.1331 - val_accuracy: 0.9265 - val_loss: 0.1567 - learning_rate: 0.0010
# Epoch 38/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9370 - loss: 0.1600 - val_accuracy: 0.9353 - val_loss: 0.1593 - learning_rate: 0.0010
# Epoch 39/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9519 - loss: 0.1212 - val_accuracy: 0.9324 - val_loss: 0.1535 - learning_rate: 0.0010
# Epoch 40/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9370 - loss: 0.1568 - val_accuracy: 0.9235 - val_loss: 0.1766 - learning_rate: 0.0010
# Epoch 41/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9378 - loss: 0.1400 - val_accuracy: 0.9294 - val_loss: 0.1536 - learning_rate: 0.0010
# Epoch 42/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9403 - loss: 0.1373 - val_accuracy: 0.9324 - val_loss: 0.1455 - learning_rate: 0.0010
# Epoch 43/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9550 - loss: 0.1236 - val_accuracy: 0.9324 - val_loss: 0.1457 - learning_rate: 5.0000e-04
# Epoch 44/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9579 - loss: 0.1163 - val_accuracy: 0.9324 - val_loss: 0.1446 - learning_rate: 5.0000e-04
# Epoch 45/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9528 - loss: 0.1227 - val_accuracy: 0.9265 - val_loss: 0.1512 - learning_rate: 5.0000e-04
# Epoch 46/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9476 - loss: 0.1323 - val_accuracy: 0.9382 - val_loss: 0.1439 - learning_rate: 5.0000e-04
# Epoch 47/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9254 - loss: 0.1386 - val_accuracy: 0.9471 - val_loss: 0.1433 - learning_rate: 5.0000e-04
# Epoch 48/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9569 - loss: 0.1047 - val_accuracy: 0.9441 - val_loss: 0.1458 - learning_rate: 5.0000e-04
# Epoch 49/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9372 - loss: 0.1456 - val_accuracy: 0.9441 - val_loss: 0.1423 - learning_rate: 5.0000e-04
# Epoch 50/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9486 - loss: 0.1165 - val_accuracy: 0.9471 - val_loss: 0.1397 - learning_rate: 5.0000e-04
# Epoch 51/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9519 - loss: 0.1079 - val_accuracy: 0.9382 - val_loss: 0.1453 - learning_rate: 5.0000e-04
# Epoch 52/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9495 - loss: 0.1261 - val_accuracy: 0.9412 - val_loss: 0.1421 - learning_rate: 5.0000e-04
# Epoch 53/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9460 - loss: 0.1218 - val_accuracy: 0.9382 - val_loss: 0.1532 - learning_rate: 5.0000e-04
# Epoch 54/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9606 - loss: 0.1017 - val_accuracy: 0.9441 - val_loss: 0.1513 - learning_rate: 5.0000e-04
# Epoch 55/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9578 - loss: 0.1078 - val_accuracy: 0.9441 - val_loss: 0.1518 - learning_rate: 5.0000e-04
# Epoch 56/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9429 - loss: 0.1650 - val_accuracy: 0.9382 - val_loss: 0.1456 - learning_rate: 5.0000e-04
# Epoch 57/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9448 - loss: 0.1165 - val_accuracy: 0.9441 - val_loss: 0.1421 - learning_rate: 5.0000e-04
# Epoch 58/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9584 - loss: 0.1101 - val_accuracy: 0.9382 - val_loss: 0.1491 - learning_rate: 5.0000e-04
# Epoch 59/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9436 - loss: 0.1133 - val_accuracy: 0.9412 - val_loss: 0.1600 - learning_rate: 5.0000e-04
# Epoch 60/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9594 - loss: 0.1122 - val_accuracy: 0.9382 - val_loss: 0.1572 - learning_rate: 5.0000e-04
# Epoch 61/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9552 - loss: 0.1069 - val_accuracy: 0.9382 - val_loss: 0.1552 - learning_rate: 2.5000e-04
# Epoch 62/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9460 - loss: 0.1173 - val_accuracy: 0.9324 - val_loss: 0.1583 - learning_rate: 2.5000e-04
# Epoch 63/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9700 - loss: 0.0914 - val_accuracy: 0.9382 - val_loss: 0.1589 - learning_rate: 2.5000e-04
# Epoch 64/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9681 - loss: 0.0878 - val_accuracy: 0.9353 - val_loss: 0.1581 - learning_rate: 2.5000e-04
# Epoch 65/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9550 - loss: 0.1159 - val_accuracy: 0.9412 - val_loss: 0.1598 - learning_rate: 2.5000e-04
#
# Базовая модель - Test Accuracy: 0.9319

# %%
print("БАЗОВАЯ МОДЕЛЬ (без предобучения)")
print("="*50)

def create_base_model(input_dim, num_classes):
    model = models.Sequential([
        layers.Dense(128, activation='relu', input_shape=(input_dim,)),
        layers.Dropout(0.3),
        layers.Dense(64, activation='relu'),
        layers.Dropout(0.3),
        layers.Dense(32, activation='relu'),
        layers.Dropout(0.2),
        layers.Dense(num_classes, activation='softmax')
    ])
    return model

input_dim = X_train_scaled.shape[1]
num_classes = len(np.unique(y_target))

base_model = create_base_model(input_dim, num_classes)
base_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

print("Архитектура базовой модели:")
base_model.summary()

history_base = base_model.fit(
    X_train_scaled, y_train,
    epochs=100,
    batch_size=32,
    validation_split=0.2,
    verbose=1,
    callbacks=[
        keras.callbacks.EarlyStopping(patience=15, restore_best_weights=True),
        keras.callbacks.ReduceLROnPlateau(patience=10, factor=0.5)
    ]
)

test_loss_base, test_accuracy_base = base_model.evaluate(X_test_scaled, y_test, verbose=0)
print(f"\nБазовая модель - Test Accuracy: {test_accuracy_base:.4f}")
# Out:
# БАЗОВАЯ МОДЕЛЬ (без предобучения)
# ==================================================
# Архитектура базовой модели:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 128)            │         2,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 3)              │            99 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,251 (51.76 KB)
#  Trainable params: 13,251 (51.76 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.4766 - loss: 1.0538 - val_accuracy: 0.8294 - val_loss: 0.4719 - learning_rate: 0.0010
# Epoch 2/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8204 - loss: 0.4761 - val_accuracy: 0.8853 - val_loss: 0.3183 - learning_rate: 0.0010
# Epoch 3/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8578 - loss: 0.4154 - val_accuracy: 0.8882 - val_loss: 0.2802 - learning_rate: 0.0010
# Epoch 4/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8656 - loss: 0.3470 - val_accuracy: 0.9000 - val_loss: 0.2497 - learning_rate: 0.0010
# Epoch 5/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8644 - loss: 0.3205 - val_accuracy: 0.9000 - val_loss: 0.2400 - learning_rate: 0.0010
# Epoch 6/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8900 - loss: 0.2749 - val_accuracy: 0.9147 - val_loss: 0.2324 - learning_rate: 0.0010
# Epoch 7/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8669 - loss: 0.2977 - val_accuracy: 0.9088 - val_loss: 0.2215 - learning_rate: 0.0010
# Epoch 8/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8791 - loss: 0.2780 - val_accuracy: 0.9088 - val_loss: 0.2139 - learning_rate: 0.0010
# Epoch 9/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8747 - loss: 0.2894 - val_accuracy: 0.9147 - val_loss: 0.2079 - learning_rate: 0.0010
# Epoch 10/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8854 - loss: 0.2704 - val_accuracy: 0.9088 - val_loss: 0.2135 - learning_rate: 0.0010
# Epoch 11/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9042 - loss: 0.2322 - val_accuracy: 0.9206 - val_loss: 0.1924 - learning_rate: 0.0010
# Epoch 12/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9035 - loss: 0.2361 - val_accuracy: 0.9265 - val_loss: 0.1953 - learning_rate: 0.0010
# Epoch 13/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9146 - loss: 0.2152 - val_accuracy: 0.9206 - val_loss: 0.1915 - learning_rate: 0.0010
# Epoch 14/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9025 - loss: 0.2200 - val_accuracy: 0.9088 - val_loss: 0.1936 - learning_rate: 0.0010
# Epoch 15/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9206 - loss: 0.2015 - val_accuracy: 0.9294 - val_loss: 0.1840 - learning_rate: 0.0010
# Epoch 16/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8818 - loss: 0.2455 - val_accuracy: 0.9206 - val_loss: 0.1816 - learning_rate: 0.0010
# Epoch 17/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8983 - loss: 0.2123 - val_accuracy: 0.9088 - val_loss: 0.1879 - learning_rate: 0.0010
# Epoch 18/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9061 - loss: 0.2123 - val_accuracy: 0.9235 - val_loss: 0.1840 - learning_rate: 0.0010
# Epoch 19/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9175 - loss: 0.1996 - val_accuracy: 0.9382 - val_loss: 0.1694 - learning_rate: 0.0010
# Epoch 20/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9132 - loss: 0.1954 - val_accuracy: 0.9118 - val_loss: 0.1843 - learning_rate: 0.0010
# Epoch 21/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9072 - loss: 0.1937 - val_accuracy: 0.9324 - val_loss: 0.1717 - learning_rate: 0.0010
# Epoch 22/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9351 - loss: 0.1643 - val_accuracy: 0.9324 - val_loss: 0.1727 - learning_rate: 0.0010
# Epoch 23/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9222 - loss: 0.1710 - val_accuracy: 0.9294 - val_loss: 0.1722 - learning_rate: 0.0010
# Epoch 24/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9144 - loss: 0.1952 - val_accuracy: 0.9324 - val_loss: 0.1662 - learning_rate: 0.0010
# Epoch 25/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9129 - loss: 0.1934 - val_accuracy: 0.9441 - val_loss: 0.1610 - learning_rate: 0.0010
# Epoch 26/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9107 - loss: 0.1967 - val_accuracy: 0.9382 - val_loss: 0.1599 - learning_rate: 0.0010
# Epoch 27/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9275 - loss: 0.1817 - val_accuracy: 0.9353 - val_loss: 0.1634 - learning_rate: 0.0010
# Epoch 28/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9154 - loss: 0.1833 - val_accuracy: 0.9235 - val_loss: 0.1654 - learning_rate: 0.0010
# Epoch 29/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9346 - loss: 0.1665 - val_accuracy: 0.9176 - val_loss: 0.1889 - learning_rate: 0.0010
# Epoch 30/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9138 - loss: 0.1984 - val_accuracy: 0.9382 - val_loss: 0.1652 - learning_rate: 0.0010
# Epoch 31/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9339 - loss: 0.1534 - val_accuracy: 0.9265 - val_loss: 0.1688 - learning_rate: 0.0010
# Epoch 32/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9359 - loss: 0.1637 - val_accuracy: 0.9353 - val_loss: 0.1584 - learning_rate: 0.0010
# Epoch 33/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9321 - loss: 0.1732 - val_accuracy: 0.9353 - val_loss: 0.1610 - learning_rate: 0.0010
# Epoch 34/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9251 - loss: 0.1568 - val_accuracy: 0.9441 - val_loss: 0.1556 - learning_rate: 0.0010
# Epoch 35/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9314 - loss: 0.1498 - val_accuracy: 0.9412 - val_loss: 0.1590 - learning_rate: 0.0010
# Epoch 36/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9347 - loss: 0.1552 - val_accuracy: 0.9324 - val_loss: 0.1681 - learning_rate: 0.0010
# Epoch 37/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9489 - loss: 0.1472 - val_accuracy: 0.9382 - val_loss: 0.1532 - learning_rate: 0.0010
# Epoch 38/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9325 - loss: 0.1457 - val_accuracy: 0.9324 - val_loss: 0.1579 - learning_rate: 0.0010
# Epoch 39/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9526 - loss: 0.1331 - val_accuracy: 0.9353 - val_loss: 0.1656 - learning_rate: 0.0010
# Epoch 40/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9288 - loss: 0.1518 - val_accuracy: 0.9441 - val_loss: 0.1477 - learning_rate: 0.0010
# Epoch 41/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9280 - loss: 0.1675 - val_accuracy: 0.9441 - val_loss: 0.1431 - learning_rate: 0.0010
# Epoch 42/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9444 - loss: 0.1268 - val_accuracy: 0.9382 - val_loss: 0.1439 - learning_rate: 0.0010
# Epoch 43/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9465 - loss: 0.1308 - val_accuracy: 0.9471 - val_loss: 0.1608 - learning_rate: 0.0010
# Epoch 44/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9477 - loss: 0.1367 - val_accuracy: 0.9324 - val_loss: 0.1470 - learning_rate: 0.0010
# Epoch 45/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9525 - loss: 0.1279 - val_accuracy: 0.9382 - val_loss: 0.1536 - learning_rate: 0.0010
# Epoch 46/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9440 - loss: 0.1314 - val_accuracy: 0.9471 - val_loss: 0.1530 - learning_rate: 0.0010
# Epoch 47/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9451 - loss: 0.1395 - val_accuracy: 0.9412 - val_loss: 0.1570 - learning_rate: 0.0010
# Epoch 48/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9499 - loss: 0.1231 - val_accuracy: 0.9412 - val_loss: 0.1715 - learning_rate: 0.0010
# Epoch 49/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9447 - loss: 0.1310 - val_accuracy: 0.9382 - val_loss: 0.1663 - learning_rate: 0.0010
# Epoch 50/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9572 - loss: 0.1201 - val_accuracy: 0.9382 - val_loss: 0.1611 - learning_rate: 0.0010
# Epoch 51/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9511 - loss: 0.1188 - val_accuracy: 0.9441 - val_loss: 0.1670 - learning_rate: 0.0010
# Epoch 52/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9441 - loss: 0.1219 - val_accuracy: 0.9412 - val_loss: 0.1587 - learning_rate: 5.0000e-04
# Epoch 53/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9339 - loss: 0.1308 - val_accuracy: 0.9500 - val_loss: 0.1606 - learning_rate: 5.0000e-04
# Epoch 54/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9580 - loss: 0.1010 - val_accuracy: 0.9471 - val_loss: 0.1570 - learning_rate: 5.0000e-04
# Epoch 55/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9606 - loss: 0.1099 - val_accuracy: 0.9471 - val_loss: 0.1606 - learning_rate: 5.0000e-04
# Epoch 56/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9531 - loss: 0.1104 - val_accuracy: 0.9559 - val_loss: 0.1642 - learning_rate: 5.0000e-04
#
# Базовая модель - Test Accuracy: 0.9272

# %%
print("RBM ПОДХОД ДЛЯ ПРЕДОБУЧЕНИЯ")
print("="*50)

class RBM:
    def __init__(self, n_visible, n_hidden, learning_rate=0.01, momentum=0.9):
        self.n_visible = n_visible
        self.n_hidden = n_hidden
        self.learning_rate = learning_rate
        self.momentum = momentum

        self.W = np.random.normal(0, 0.01, (n_visible, n_hidden))
        self.v_bias = np.zeros(n_visible)
        self.h_bias = np.zeros(n_hidden)

        self.W_inc = np.zeros((n_visible, n_hidden))
        self.v_bias_inc = np.zeros(n_visible)
        self.h_bias_inc = np.zeros(n_hidden)

    def sigmoid(self, x):
        return 1 / (1 + np.exp(-np.clip(x, -250, 250)))

    def sample_hidden(self, visible):
        activation = np.dot(visible, self.W) + self.h_bias
        p_hidden = self.sigmoid(activation)
        return p_hidden, np.random.binomial(1, p_hidden)

    def sample_visible(self, hidden):
        activation = np.dot(hidden, self.W.T) + self.v_bias
        p_visible = self.sigmoid(activation)
        return p_visible, np.random.binomial(1, p_visible)

    def contrastive_divergence(self, input_data, k=1):
        pos_hidden_probs, pos_hidden_states = self.sample_hidden(input_data)

        hidden_states = pos_hidden_states
        for _ in range(k):
            neg_visible_probs, neg_visible_states = self.sample_visible(hidden_states)
            neg_hidden_probs, neg_hidden_states = self.sample_hidden(neg_visible_states)
            hidden_states = neg_hidden_states

        positive_associations = np.dot(input_data.T, pos_hidden_probs)
        negative_associations = np.dot(neg_visible_states.T, neg_hidden_probs)

        self.W_inc = self.momentum * self.W_inc + \
                    self.learning_rate * ((positive_associations - negative_associations) / len(input_data))
        self.v_bias_inc = self.momentum * self.v_bias_inc + \
                         self.learning_rate * np.mean(input_data - neg_visible_states, axis=0)
        self.h_bias_inc = self.momentum * self.h_bias_inc + \
                         self.learning_rate * np.mean(pos_hidden_probs - neg_hidden_probs, axis=0)

        self.W += self.W_inc
        self.v_bias += self.v_bias_inc
        self.h_bias += self.h_bias_inc

        reconstruction_error = np.mean((input_data - neg_visible_probs) ** 2)
        return reconstruction_error

    def transform(self, data):
        hidden_probs, _ = self.sample_hidden(data)
        return hidden_probs

    def get_weights(self):
        return [self.W, self.h_bias]

print("Предобучение RBM...")

X_min = X_train_scaled.min()
X_max = X_train_scaled.max()
X_train_rbm = (X_train_scaled - X_min) / (X_max - X_min)
X_test_rbm = (X_test_scaled - X_min) / (X_max - X_min)

pretrained_weights_rbm = []

print("1. Обучение первого RBM слоя:")
rbm1 = RBM(n_visible=input_dim, n_hidden=128, learning_rate=0.01, momentum=0.9)

rbm1_errors = []
for epoch in range(100):
    error = rbm1.contrastive_divergence(X_train_rbm, k=1)
    rbm1_errors.append(error)
    if epoch % 20 == 0:
        print(f"   Epoch {epoch}, Reconstruction Error: {error:.4f}")

pretrained_weights_rbm.append(rbm1.get_weights())
hidden1_output = rbm1.transform(X_train_rbm)

print("2. Обучение второго RBM слоя:")
rbm2 = RBM(n_visible=128, n_hidden=64, learning_rate=0.01, momentum=0.9)

rbm2_errors = []
for epoch in range(100):
    error = rbm2.contrastive_divergence(hidden1_output, k=1)
    rbm2_errors.append(error)
    if epoch % 20 == 0:
        print(f"   Epoch {epoch}, Reconstruction Error: {error:.4f}")

pretrained_weights_rbm.append(rbm2.get_weights())
hidden2_output = rbm2.transform(hidden1_output)

print("3. Обучение третьего RBM слоя:")
rbm3 = RBM(n_visible=64, n_hidden=32, learning_rate=0.01, momentum=0.9)

rbm3_errors = []
for epoch in range(100):
    error = rbm3.contrastive_divergence(hidden2_output, k=1)
    rbm3_errors.append(error)
    if epoch % 20 == 0:
        print(f"   Epoch {epoch}, Reconstruction Error: {error:.4f}")

pretrained_weights_rbm.append(rbm3.get_weights())

print("Все RBM слои обучены!")

plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.plot(rbm1_errors, color='blue', linewidth=2)
plt.title('RBM 1 - Ошибки реконструкции')
plt.xlabel('Epoch')
plt.ylabel('Reconstruction Error')
plt.grid(True, alpha=0.3)

plt.subplot(1, 3, 2)
plt.plot(rbm2_errors, color='red', linewidth=2)
plt.title('RBM 2 - Ошибки реконструкции')
plt.xlabel('Epoch')
plt.ylabel('Reconstruction Error')
plt.grid(True, alpha=0.3)

plt.subplot(1, 3, 3)
plt.plot(rbm3_errors, color='green', linewidth=2)
plt.title('RBM 3 - Ошибки реконструкции')
plt.xlabel('Epoch')
plt.ylabel('Reconstruction Error')
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# RBM ПОДХОД ДЛЯ ПРЕДОБУЧЕНИЯ
# ==================================================
# Предобучение RBM...
# 1. Обучение первого RBM слоя:
#    Epoch 0, Reconstruction Error: 0.0905
#    Epoch 20, Reconstruction Error: 0.0048
#    Epoch 40, Reconstruction Error: 0.0024
#    Epoch 60, Reconstruction Error: 0.0025
#    Epoch 80, Reconstruction Error: 0.0023
# 2. Обучение второго RBM слоя:
#    Epoch 0, Reconstruction Error: 0.0008
#    Epoch 20, Reconstruction Error: 0.0002
#    Epoch 40, Reconstruction Error: 0.0001
#    Epoch 60, Reconstruction Error: 0.0001
#    Epoch 80, Reconstruction Error: 0.0001
# 3. Обучение третьего RBM слоя:
#    Epoch 0, Reconstruction Error: 0.0027
#    Epoch 20, Reconstruction Error: 0.0002
#    Epoch 40, Reconstruction Error: 0.0002
#    Epoch 60, Reconstruction Error: 0.0001
#    Epoch 80, Reconstruction Error: 0.0001
# Все RBM слои обучены!

# %%
print("СОЗДАНИЕ МОДЕЛИ С RBM ПРЕДОБУЧЕНИЕМ")
print("="*50)

pretrained_model_rbm = models.Sequential()
pretrained_model_rbm.add(layers.Dense(128, activation='sigmoid', input_shape=(input_dim,), name='pretrained_layer1'))
pretrained_model_rbm.add(layers.Dropout(0.3))
pretrained_model_rbm.add(layers.Dense(64, activation='sigmoid', name='pretrained_layer2'))
pretrained_model_rbm.add(layers.Dropout(0.3))
pretrained_model_rbm.add(layers.Dense(32, activation='sigmoid', name='pretrained_layer3'))
pretrained_model_rbm.add(layers.Dropout(0.2))
pretrained_model_rbm.add(layers.Dense(num_classes, activation='softmax', name='output_layer'))

print("Установка предобученных весов RBM...")
pretrained_model_rbm.layers[0].set_weights([pretrained_weights_rbm[0][0], pretrained_weights_rbm[0][1]])
pretrained_model_rbm.layers[2].set_weights([pretrained_weights_rbm[1][0], pretrained_weights_rbm[1][1]])
pretrained_model_rbm.layers[4].set_weights([pretrained_weights_rbm[2][0], pretrained_weights_rbm[2][1]])

pretrained_model_rbm.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

print("Архитектура модели с RBM предобучением:")
pretrained_model_rbm.summary()

print("ОБУЧЕНИЕ С УЧИТЕЛЕМ")
print("="*50)

history_pretrained_rbm = pretrained_model_rbm.fit(
    X_train_scaled, y_train,
    epochs=100,
    batch_size=32,
    validation_split=0.2,
    verbose=1,
    callbacks=[
        keras.callbacks.EarlyStopping(patience=15, restore_best_weights=True),
        keras.callbacks.ReduceLROnPlateau(patience=10, factor=0.5)
    ]
)

test_loss_rbm, test_accuracy_rbm = pretrained_model_rbm.evaluate(X_test_scaled, y_test, verbose=0)
print(f"\nМодель с RBM предобучением - Test Accuracy: {test_accuracy_rbm:.4f}")
# Out:
# СОЗДАНИЕ МОДЕЛИ С RBM ПРЕДОБУЧЕНИЕМ
# ==================================================
# Установка предобученных весов RBM...
# Архитектура модели с RBM предобучением:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ pretrained_layer1 (Dense)       │ (None, 128)            │         2,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pretrained_layer2 (Dense)       │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pretrained_layer3 (Dense)       │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 3)              │            99 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,251 (51.76 KB)
#  Trainable params: 13,251 (51.76 KB)
#  Non-trainable params: 0 (0.00 B)
# ОБУЧЕНИЕ С УЧИТЕЛЕМ
# ==================================================
# Epoch 1/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 61ms/step - accuracy: 0.7914 - loss: 0.7145 - val_accuracy: 0.7765 - val_loss: 0.6942 - learning_rate: 0.0010
# Epoch 2/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7968 - loss: 0.6638 - val_accuracy: 0.7765 - val_loss: 0.6895 - learning_rate: 0.0010
# Epoch 3/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7706 - loss: 0.6961 - val_accuracy: 0.7765 - val_loss: 0.6746 - learning_rate: 0.0010
# Epoch 4/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7812 - loss: 0.6661 - val_accuracy: 0.7765 - val_loss: 0.6144 - learning_rate: 0.0010
# Epoch 5/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7887 - loss: 0.5799 - val_accuracy: 0.7765 - val_loss: 0.5162 - learning_rate: 0.0010
# Epoch 6/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7919 - loss: 0.4898 - val_accuracy: 0.7765 - val_loss: 0.4463 - learning_rate: 0.0010
# Epoch 7/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8107 - loss: 0.4108 - val_accuracy: 0.8000 - val_loss: 0.4142 - learning_rate: 0.0010
# Epoch 8/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8248 - loss: 0.4081 - val_accuracy: 0.8147 - val_loss: 0.3956 - learning_rate: 0.0010
# Epoch 9/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8123 - loss: 0.4089 - val_accuracy: 0.8176 - val_loss: 0.3886 - learning_rate: 0.0010
# Epoch 10/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8328 - loss: 0.3675 - val_accuracy: 0.8147 - val_loss: 0.3806 - learning_rate: 0.0010
# Epoch 11/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8169 - loss: 0.3984 - val_accuracy: 0.8118 - val_loss: 0.3741 - learning_rate: 0.0010
# Epoch 12/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8170 - loss: 0.3889 - val_accuracy: 0.8118 - val_loss: 0.3638 - learning_rate: 0.0010
# Epoch 13/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8332 - loss: 0.3957 - val_accuracy: 0.8147 - val_loss: 0.3591 - learning_rate: 0.0010
# Epoch 14/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8247 - loss: 0.3927 - val_accuracy: 0.8382 - val_loss: 0.3593 - learning_rate: 0.0010
# Epoch 15/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8688 - loss: 0.3196 - val_accuracy: 0.8500 - val_loss: 0.3572 - learning_rate: 0.0010
# Epoch 16/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8509 - loss: 0.3648 - val_accuracy: 0.8529 - val_loss: 0.3499 - learning_rate: 0.0010
# Epoch 17/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8553 - loss: 0.3603 - val_accuracy: 0.8706 - val_loss: 0.3439 - learning_rate: 0.0010
# Epoch 18/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8427 - loss: 0.3572 - val_accuracy: 0.8618 - val_loss: 0.3409 - learning_rate: 0.0010
# Epoch 19/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8390 - loss: 0.3695 - val_accuracy: 0.8588 - val_loss: 0.3431 - learning_rate: 0.0010
# Epoch 20/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8509 - loss: 0.3400 - val_accuracy: 0.8618 - val_loss: 0.3328 - learning_rate: 0.0010
# Epoch 21/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8514 - loss: 0.3430 - val_accuracy: 0.8676 - val_loss: 0.3278 - learning_rate: 0.0010
# Epoch 22/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8624 - loss: 0.3224 - val_accuracy: 0.8735 - val_loss: 0.3250 - learning_rate: 0.0010
# Epoch 23/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8771 - loss: 0.3207 - val_accuracy: 0.8824 - val_loss: 0.3234 - learning_rate: 0.0010
# Epoch 24/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8644 - loss: 0.3351 - val_accuracy: 0.8618 - val_loss: 0.3163 - learning_rate: 0.0010
# Epoch 25/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8814 - loss: 0.3063 - val_accuracy: 0.8706 - val_loss: 0.3173 - learning_rate: 0.0010
# Epoch 26/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8609 - loss: 0.3228 - val_accuracy: 0.8647 - val_loss: 0.3081 - learning_rate: 0.0010
# Epoch 27/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8725 - loss: 0.3183 - val_accuracy: 0.8794 - val_loss: 0.3057 - learning_rate: 0.0010
# Epoch 28/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8710 - loss: 0.3097 - val_accuracy: 0.8706 - val_loss: 0.3011 - learning_rate: 0.0010
# Epoch 29/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8903 - loss: 0.3033 - val_accuracy: 0.8706 - val_loss: 0.3000 - learning_rate: 0.0010
# Epoch 30/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8714 - loss: 0.3322 - val_accuracy: 0.8824 - val_loss: 0.2966 - learning_rate: 0.0010
# Epoch 31/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8832 - loss: 0.3054 - val_accuracy: 0.8824 - val_loss: 0.2913 - learning_rate: 0.0010
# Epoch 32/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8585 - loss: 0.3210 - val_accuracy: 0.8706 - val_loss: 0.2892 - learning_rate: 0.0010
# Epoch 33/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8746 - loss: 0.2931 - val_accuracy: 0.8882 - val_loss: 0.2929 - learning_rate: 0.0010
# Epoch 34/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8638 - loss: 0.3087 - val_accuracy: 0.8735 - val_loss: 0.2828 - learning_rate: 0.0010
# Epoch 35/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8518 - loss: 0.3260 - val_accuracy: 0.8912 - val_loss: 0.2824 - learning_rate: 0.0010
# Epoch 36/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8759 - loss: 0.3217 - val_accuracy: 0.8882 - val_loss: 0.2755 - learning_rate: 0.0010
# Epoch 37/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8768 - loss: 0.2973 - val_accuracy: 0.8912 - val_loss: 0.2731 - learning_rate: 0.0010
# Epoch 38/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8768 - loss: 0.3091 - val_accuracy: 0.8912 - val_loss: 0.2711 - learning_rate: 0.0010
# Epoch 39/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8815 - loss: 0.2903 - val_accuracy: 0.8971 - val_loss: 0.2718 - learning_rate: 0.0010
# Epoch 40/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8753 - loss: 0.2939 - val_accuracy: 0.8971 - val_loss: 0.2709 - learning_rate: 0.0010
# Epoch 41/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8779 - loss: 0.3010 - val_accuracy: 0.9029 - val_loss: 0.2644 - learning_rate: 0.0010
# Epoch 42/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8718 - loss: 0.2859 - val_accuracy: 0.8971 - val_loss: 0.2639 - learning_rate: 0.0010
# Epoch 43/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8737 - loss: 0.3005 - val_accuracy: 0.9029 - val_loss: 0.2639 - learning_rate: 0.0010
# Epoch 44/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8687 - loss: 0.3181 - val_accuracy: 0.9059 - val_loss: 0.2605 - learning_rate: 0.0010
# Epoch 45/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8789 - loss: 0.2997 - val_accuracy: 0.9059 - val_loss: 0.2552 - learning_rate: 0.0010
# Epoch 46/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8907 - loss: 0.2868 - val_accuracy: 0.9029 - val_loss: 0.2547 - learning_rate: 0.0010
# Epoch 47/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8835 - loss: 0.2677 - val_accuracy: 0.9059 - val_loss: 0.2548 - learning_rate: 0.0010
# Epoch 48/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8752 - loss: 0.3061 - val_accuracy: 0.9029 - val_loss: 0.2501 - learning_rate: 0.0010
# Epoch 49/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8888 - loss: 0.3016 - val_accuracy: 0.9088 - val_loss: 0.2482 - learning_rate: 0.0010
# Epoch 50/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8802 - loss: 0.2909 - val_accuracy: 0.9059 - val_loss: 0.2446 - learning_rate: 0.0010
# Epoch 51/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8778 - loss: 0.2927 - val_accuracy: 0.9088 - val_loss: 0.2420 - learning_rate: 0.0010
# Epoch 52/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8753 - loss: 0.2986 - val_accuracy: 0.9088 - val_loss: 0.2440 - learning_rate: 0.0010
# Epoch 53/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8795 - loss: 0.2756 - val_accuracy: 0.9059 - val_loss: 0.2424 - learning_rate: 0.0010
# Epoch 54/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8822 - loss: 0.2940 - val_accuracy: 0.9118 - val_loss: 0.2384 - learning_rate: 0.0010
# Epoch 55/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8752 - loss: 0.2898 - val_accuracy: 0.9118 - val_loss: 0.2478 - learning_rate: 0.0010
# Epoch 56/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8877 - loss: 0.2796 - val_accuracy: 0.9147 - val_loss: 0.2352 - learning_rate: 0.0010
# Epoch 57/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8803 - loss: 0.2800 - val_accuracy: 0.9029 - val_loss: 0.2322 - learning_rate: 0.0010
# Epoch 58/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8812 - loss: 0.2674 - val_accuracy: 0.9059 - val_loss: 0.2372 - learning_rate: 0.0010
# Epoch 59/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8911 - loss: 0.2691 - val_accuracy: 0.9059 - val_loss: 0.2310 - learning_rate: 0.0010
# Epoch 60/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8674 - loss: 0.2924 - val_accuracy: 0.9059 - val_loss: 0.2343 - learning_rate: 0.0010
# Epoch 61/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9028 - loss: 0.2621 - val_accuracy: 0.9029 - val_loss: 0.2274 - learning_rate: 0.0010
# Epoch 62/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8981 - loss: 0.2620 - val_accuracy: 0.9118 - val_loss: 0.2326 - learning_rate: 0.0010
# Epoch 63/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8882 - loss: 0.2831 - val_accuracy: 0.9118 - val_loss: 0.2264 - learning_rate: 0.0010
# Epoch 64/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8791 - loss: 0.2920 - val_accuracy: 0.9059 - val_loss: 0.2233 - learning_rate: 0.0010
# Epoch 65/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8841 - loss: 0.2724 - val_accuracy: 0.9118 - val_loss: 0.2215 - learning_rate: 0.0010
# Epoch 66/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8953 - loss: 0.2934 - val_accuracy: 0.9088 - val_loss: 0.2216 - learning_rate: 0.0010
# Epoch 67/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8883 - loss: 0.2814 - val_accuracy: 0.9059 - val_loss: 0.2217 - learning_rate: 0.0010
# Epoch 68/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8841 - loss: 0.2716 - val_accuracy: 0.9118 - val_loss: 0.2211 - learning_rate: 0.0010
# Epoch 69/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8867 - loss: 0.2624 - val_accuracy: 0.9088 - val_loss: 0.2181 - learning_rate: 0.0010
# Epoch 70/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8925 - loss: 0.2665 - val_accuracy: 0.9118 - val_loss: 0.2211 - learning_rate: 0.0010
# Epoch 71/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8973 - loss: 0.2680 - val_accuracy: 0.9059 - val_loss: 0.2163 - learning_rate: 0.0010
# Epoch 72/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8918 - loss: 0.2550 - val_accuracy: 0.9118 - val_loss: 0.2170 - learning_rate: 0.0010
# Epoch 73/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8944 - loss: 0.2625 - val_accuracy: 0.9088 - val_loss: 0.2177 - learning_rate: 0.0010
# Epoch 74/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8994 - loss: 0.2379 - val_accuracy: 0.9118 - val_loss: 0.2146 - learning_rate: 0.0010
# Epoch 75/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8824 - loss: 0.2791 - val_accuracy: 0.9147 - val_loss: 0.2153 - learning_rate: 0.0010
# Epoch 76/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9128 - loss: 0.2314 - val_accuracy: 0.9059 - val_loss: 0.2154 - learning_rate: 0.0010
# Epoch 77/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8859 - loss: 0.2593 - val_accuracy: 0.9176 - val_loss: 0.2122 - learning_rate: 0.0010
# Epoch 78/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8897 - loss: 0.2624 - val_accuracy: 0.9118 - val_loss: 0.2110 - learning_rate: 0.0010
# Epoch 79/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8871 - loss: 0.2522 - val_accuracy: 0.9147 - val_loss: 0.2166 - learning_rate: 0.0010
# Epoch 80/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8884 - loss: 0.2587 - val_accuracy: 0.9147 - val_loss: 0.2125 - learning_rate: 0.0010
# Epoch 81/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8800 - loss: 0.2672 - val_accuracy: 0.9088 - val_loss: 0.2131 - learning_rate: 0.0010
# Epoch 82/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9053 - loss: 0.2247 - val_accuracy: 0.9088 - val_loss: 0.2108 - learning_rate: 0.0010
# Epoch 83/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8823 - loss: 0.2722 - val_accuracy: 0.9059 - val_loss: 0.2103 - learning_rate: 0.0010
# Epoch 84/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8845 - loss: 0.2655 - val_accuracy: 0.9088 - val_loss: 0.2110 - learning_rate: 0.0010
# Epoch 85/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8870 - loss: 0.2594 - val_accuracy: 0.9059 - val_loss: 0.2130 - learning_rate: 0.0010
# Epoch 86/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8909 - loss: 0.2751 - val_accuracy: 0.9118 - val_loss: 0.2125 - learning_rate: 0.0010
# Epoch 87/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8891 - loss: 0.2501 - val_accuracy: 0.9176 - val_loss: 0.2086 - learning_rate: 0.0010
# Epoch 88/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8962 - loss: 0.2455 - val_accuracy: 0.9206 - val_loss: 0.2103 - learning_rate: 0.0010
# Epoch 89/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8995 - loss: 0.2360 - val_accuracy: 0.9176 - val_loss: 0.2119 - learning_rate: 0.0010
# Epoch 90/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8968 - loss: 0.2371 - val_accuracy: 0.9029 - val_loss: 0.2143 - learning_rate: 0.0010
# Epoch 91/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8946 - loss: 0.2470 - val_accuracy: 0.9029 - val_loss: 0.2132 - learning_rate: 0.0010
# Epoch 92/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9009 - loss: 0.2460 - val_accuracy: 0.9088 - val_loss: 0.2127 - learning_rate: 0.0010
# Epoch 93/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8945 - loss: 0.2644 - val_accuracy: 0.9118 - val_loss: 0.2109 - learning_rate: 0.0010
# Epoch 94/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9012 - loss: 0.2489 - val_accuracy: 0.9118 - val_loss: 0.2095 - learning_rate: 0.0010
# Epoch 95/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9002 - loss: 0.2334 - val_accuracy: 0.9206 - val_loss: 0.2085 - learning_rate: 0.0010
# Epoch 96/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8960 - loss: 0.2444 - val_accuracy: 0.9118 - val_loss: 0.2090 - learning_rate: 0.0010
# Epoch 97/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8887 - loss: 0.2493 - val_accuracy: 0.9088 - val_loss: 0.2097 - learning_rate: 0.0010
# Epoch 98/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8948 - loss: 0.2294 - val_accuracy: 0.9118 - val_loss: 0.2078 - learning_rate: 0.0010
# Epoch 99/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8914 - loss: 0.2485 - val_accuracy: 0.9176 - val_loss: 0.2078 - learning_rate: 0.0010
# Epoch 100/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8864 - loss: 0.2552 - val_accuracy: 0.9235 - val_loss: 0.2083 - learning_rate: 0.0010
#
# Модель с RBM предобучением - Test Accuracy: 0.8779

# %%
print("ВИЗУАЛИЗАЦИЯ ПРОЦЕССА ОБУЧЕНИЯ")
print("="*50)

plt.figure(figsize=(15, 10))

plt.subplot(2, 3, 1)
min_epochs = min(len(history_base.history['val_accuracy']),
                 len(history_pretrained_rbm.history['val_accuracy']))
epochs_range = range(min_epochs)

plt.plot(epochs_range, history_base.history['val_accuracy'][:min_epochs],
         label='Базовая модель', linewidth=2, color='blue')
plt.plot(epochs_range, history_pretrained_rbm.history['val_accuracy'][:min_epochs],
         label='RBM предобучение', linewidth=2, color='green')
plt.title('Сравнение валидационной точности', fontsize=14, fontweight='bold')
plt.xlabel('Epoch')
plt.ylabel('Validation Accuracy')
plt.legend()
plt.grid(True, alpha=0.3)

plt.subplot(2, 3, 2)
plt.plot(epochs_range, history_base.history['val_loss'][:min_epochs],
         label='Базовая модель', linewidth=2, color='blue')
plt.plot(epochs_range, history_pretrained_rbm.history['val_loss'][:min_epochs],
         label='RBM предобучение', linewidth=2, color='green')
plt.title('Сравнение валидационных потерь', fontsize=14, fontweight='bold')
plt.xlabel('Epoch')
plt.ylabel('Validation Loss')
plt.legend()
plt.grid(True, alpha=0.3)

plt.subplot(2, 3, 3)
plt.plot(history_base.history['accuracy'], label='Базовая модель', linewidth=2, color='blue', alpha=0.7)
plt.plot(history_pretrained_rbm.history['accuracy'], label='RBM предобучение', linewidth=2, color='green', alpha=0.7)
plt.title('Точность на обучающей выборке', fontsize=14, fontweight='bold')
plt.xlabel('Epoch')
plt.ylabel('Training Accuracy')
plt.legend()
plt.grid(True, alpha=0.3)

plt.subplot(2, 3, 4)
plt.plot(history_base.history['loss'], label='Базовая модель', linewidth=2, color='blue', alpha=0.7)
plt.plot(history_pretrained_rbm.history['loss'], label='RBM предобучение', linewidth=2, color='green', alpha=0.7)
plt.title('Потери на обучающей выборке', fontsize=14, fontweight='bold')
plt.xlabel('Epoch')
plt.ylabel('Training Loss')
plt.legend()
plt.grid(True, alpha=0.3)

plt.subplot(2, 3, 5)
models_names = ['Базовая модель', 'RBM предобучение']
accuracies = [test_accuracy_base, test_accuracy_rbm]
colors = ['skyblue', 'lightgreen']
bars = plt.bar(models_names, accuracies, color=colors, alpha=0.8)
plt.title('Сравнение итоговой точности', fontsize=14, fontweight='bold')
plt.ylabel('Test Accuracy')
plt.ylim(0, 1)
for bar, acc in zip(bars, accuracies):
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.01,
             f'{acc:.4f}', ha='center', va='bottom', fontweight='bold')

plt.subplot(2, 3, 6)
improvement = (test_accuracy_rbm - test_accuracy_base) * 100
colors_imp = ['red' if improvement < 0 else 'green']
plt.bar(['Улучшение'], [improvement], color=colors_imp, alpha=0.8)
plt.title('Улучшение точности RBM', fontsize=14, fontweight='bold')
plt.ylabel('Improvement (%)')
plt.axhline(y=0, color='black', linestyle='-', alpha=0.3)
plt.text(0, improvement + (1 if improvement > 0 else -1),
         f'{improvement:+.2f}%', ha='center', va='bottom' if improvement > 0 else 'top',
         fontweight='bold', fontsize=12)

plt.tight_layout()
plt.show()
# Out:
# ВИЗУАЛИЗАЦИЯ ПРОЦЕССА ОБУЧЕНИЯ
# ==================================================

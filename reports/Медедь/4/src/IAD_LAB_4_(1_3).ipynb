# %%
# !pip install ucimlrepo
# !pip install tensorflow
# !pip install scikit-learn

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, f1_score
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from ucimlrepo import fetch_ucirepo
import warnings
warnings.filterwarnings('ignore')

print("TensorFlow version:", tf.__version__)
# Out:
# Requirement already satisfied: ucimlrepo in /usr/local/lib/python3.12/dist-packages (0.0.7)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ucimlrepo) (2.2.2)
# Requirement already satisfied: certifi>=2020.12.5 in /usr/local/lib/python3.12/dist-packages (from ucimlrepo) (2025.10.5)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->ucimlrepo) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->ucimlrepo) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->ucimlrepo) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->ucimlrepo) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.17.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.10.5)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.10)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# TensorFlow version: 2.19.0

# %%
print("ЗАГРУЗКА ДАТАСЕТА OPTICAL RECOGNITION OF HANDWRITTEN DIGITS")
print("="*60)

optical_digits = fetch_ucirepo(id=80)

X = optical_digits.data.features
y = optical_digits.data.targets

print("Информация о датасете Optical Digits:")
print(f"Размерность признаков (X): {X.shape}")
print(f"Размерность целевой переменной (y): {y.shape}")

print("\nНазвания признаков:")
print(X.columns.tolist()[:10])

print("\nНазвания целевых переменных:")
print(y.columns.tolist())

print("\nУникальные значения в class:")
print(y['class'].value_counts().sort_index())
# Out:
# ЗАГРУЗКА ДАТАСЕТА OPTICAL RECOGNITION OF HANDWRITTEN DIGITS
# ============================================================
# Информация о датасете Optical Digits:
# Размерность признаков (X): (5620, 64)
# Размерность целевой переменной (y): (5620, 1)
#
# Названия признаков:
# ['Attribute1', 'Attribute2', 'Attribute3', 'Attribute4', 'Attribute5', 'Attribute6', 'Attribute7', 'Attribute8', 'Attribute9', 'Attribute10']
#
# Названия целевых переменных:
# ['class']
#
# Уникальные значения в class:
# class
# 0    554
# 1    571
# 2    557
# 3    572
# 4    568
# 5    558
# 6    558
# 7    566
# 8    554
# 9    562
# Name: count, dtype: int64

# %%
print("ПРЕДОБРАБОТКА ДАННЫХ")
print("="*50)

print(f"Пропущенные значения в X: {X.isnull().sum().sum()}")
print(f"Пропущенные значения в y: {y.isnull().sum().sum()}")

if X.isnull().sum().sum() > 0:
    print("Заполняем пропущенные значения...")
    X = X.fillna(X.mean())

y_target = y['class'].values

print(f"\nРаспределение классов в целевой переменной:")
class_distribution = pd.Series(y_target).value_counts().sort_index()
print(class_distribution)

class_names = {
    0: 'Digit 0',
    1: 'Digit 1',
    2: 'Digit 2',
    3: 'Digit 3',
    4: 'Digit 4',
    5: 'Digit 5',
    6: 'Digit 6',
    7: 'Digit 7',
    8: 'Digit 8',
    9: 'Digit 9'
}

print("\nСоответствие классов:")
for class_id, class_name in class_names.items():
    count = class_distribution.get(class_id, 0)
    print(f"Класс {class_id} ({class_name}): {count} примеров")

plt.figure(figsize=(12, 6))
plt.bar(class_names.values(), class_distribution.values, color=plt.cm.Set3(np.linspace(0, 1, 10)))
plt.title('Распределение классов в датасете Handwritten Digits')
plt.ylabel('Количество примеров')
plt.xlabel('Класс')
plt.xticks(rotation=45)
plt.grid(True, alpha=0.3)
plt.show()

print("\nВизуализация примеров handwritten digits:")

def plot_digits_samples(X, y, num_samples=10):
    plt.figure(figsize=(15, 6))
    for i in range(num_samples):
        plt.subplot(2, 5, i + 1)
        digit_pixels = X.iloc[i].values.reshape(8, 8)
        plt.imshow(digit_pixels, cmap='gray')
        plt.title(f'Class: {y[i]}')
        plt.axis('off')
    plt.tight_layout()
    plt.show()

plot_digits_samples(X, y_target)

X_train, X_test, y_train, y_test = train_test_split(
    X, y_target, test_size=0.2, random_state=42, stratify=y_target
)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

print(f"\nРазмер train выборки: {X_train_scaled.shape}")
print(f"Размер test выборки: {X_test_scaled.shape}")
print(f"Количество классов: {len(np.unique(y_target))}")
print(f"Количество признаков: {X_train_scaled.shape[1]}")
# Out:
# ПРЕДОБРАБОТКА ДАННЫХ
# ==================================================
# Пропущенные значения в X: 0
# Пропущенные значения в y: 0
#
# Распределение классов в целевой переменной:
# 0    554
# 1    571
# 2    557
# 3    572
# 4    568
# 5    558
# 6    558
# 7    566
# 8    554
# 9    562
# Name: count, dtype: int64
#
# Соответствие классов:
# Класс 0 (Digit 0): 554 примеров
# Класс 1 (Digit 1): 571 примеров
# Класс 2 (Digit 2): 557 примеров
# Класс 3 (Digit 3): 572 примеров
# Класс 4 (Digit 4): 568 примеров
# Класс 5 (Digit 5): 558 примеров
# Класс 6 (Digit 6): 558 примеров
# Класс 7 (Digit 7): 566 примеров
# Класс 8 (Digit 8): 554 примеров
# Класс 9 (Digit 9): 562 примеров
# Визуализация примеров handwritten digits:
# Размер train выборки: (4496, 64)
# Размер test выборки: (1124, 64)
# Количество классов: 10
# Количество признаков: 64

# %%
print("БАЗОВАЯ МОДЕЛЬ (без предобучения)")
print("="*50)

def create_base_model(input_dim, num_classes):
    model = models.Sequential([
        layers.Dense(128, activation='relu', input_shape=(input_dim,)),
        layers.Dropout(0.3),
        layers.Dense(64, activation='relu'),
        layers.Dropout(0.3),
        layers.Dense(32, activation='relu'),
        layers.Dropout(0.2),
        layers.Dense(num_classes, activation='softmax')
    ])
    return model

input_dim = X_train_scaled.shape[1]
num_classes = len(np.unique(y_target))

base_model = create_base_model(input_dim, num_classes)
base_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

print("Архитектура базовой модели:")
base_model.summary()

history_base = base_model.fit(
    X_train_scaled, y_train,
    epochs=100,
    batch_size=32,
    validation_split=0.2,
    verbose=1,
    callbacks=[
        keras.callbacks.EarlyStopping(patience=15, restore_best_weights=True),
        keras.callbacks.ReduceLROnPlateau(patience=10, factor=0.5)
    ]
)

test_loss_base, test_accuracy_base = base_model.evaluate(X_test_scaled, y_test, verbose=0)
print(f"\nБазовая модель - Test Accuracy: {test_accuracy_base:.4f}")
# Out:
# БАЗОВАЯ МОДЕЛЬ (без предобучения)
# ==================================================
# Архитектура базовой модели:
# Model: "sequential_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 10)             │           330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 18,986 (74.16 KB)
#  Trainable params: 18,986 (74.16 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2956 - loss: 2.0470 - val_accuracy: 0.8678 - val_loss: 0.6764 - learning_rate: 0.0010
# Epoch 2/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7624 - loss: 0.7993 - val_accuracy: 0.9300 - val_loss: 0.2377 - learning_rate: 0.0010
# Epoch 3/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8782 - loss: 0.4052 - val_accuracy: 0.9467 - val_loss: 0.1669 - learning_rate: 0.0010
# Epoch 4/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9023 - loss: 0.3104 - val_accuracy: 0.9511 - val_loss: 0.1603 - learning_rate: 0.0010
# Epoch 5/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9240 - loss: 0.2478 - val_accuracy: 0.9600 - val_loss: 0.1299 - learning_rate: 0.0010
# Epoch 6/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9403 - loss: 0.2120 - val_accuracy: 0.9544 - val_loss: 0.1286 - learning_rate: 0.0010
# Epoch 7/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9438 - loss: 0.1979 - val_accuracy: 0.9600 - val_loss: 0.1219 - learning_rate: 0.0010
# Epoch 8/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9490 - loss: 0.1686 - val_accuracy: 0.9644 - val_loss: 0.1123 - learning_rate: 0.0010
# Epoch 9/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9514 - loss: 0.1566 - val_accuracy: 0.9644 - val_loss: 0.1148 - learning_rate: 0.0010
# Epoch 10/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9611 - loss: 0.1296 - val_accuracy: 0.9700 - val_loss: 0.0977 - learning_rate: 0.0010
# Epoch 11/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9626 - loss: 0.1407 - val_accuracy: 0.9700 - val_loss: 0.0945 - learning_rate: 0.0010
# Epoch 12/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9668 - loss: 0.1246 - val_accuracy: 0.9722 - val_loss: 0.1029 - learning_rate: 0.0010
# Epoch 13/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9553 - loss: 0.1397 - val_accuracy: 0.9733 - val_loss: 0.0985 - learning_rate: 0.0010
# Epoch 14/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9675 - loss: 0.1104 - val_accuracy: 0.9722 - val_loss: 0.0922 - learning_rate: 0.0010
# Epoch 15/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9661 - loss: 0.1083 - val_accuracy: 0.9733 - val_loss: 0.0919 - learning_rate: 0.0010
# Epoch 16/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9723 - loss: 0.0904 - val_accuracy: 0.9767 - val_loss: 0.0974 - learning_rate: 0.0010
# Epoch 17/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9734 - loss: 0.0896 - val_accuracy: 0.9789 - val_loss: 0.0829 - learning_rate: 0.0010
# Epoch 18/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9753 - loss: 0.0815 - val_accuracy: 0.9778 - val_loss: 0.0903 - learning_rate: 0.0010
# Epoch 19/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9750 - loss: 0.0760 - val_accuracy: 0.9789 - val_loss: 0.0899 - learning_rate: 0.0010
# Epoch 20/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9736 - loss: 0.0785 - val_accuracy: 0.9789 - val_loss: 0.0872 - learning_rate: 0.0010
# Epoch 21/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9834 - loss: 0.0602 - val_accuracy: 0.9767 - val_loss: 0.0985 - learning_rate: 0.0010
# Epoch 22/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9772 - loss: 0.0594 - val_accuracy: 0.9722 - val_loss: 0.0913 - learning_rate: 0.0010
# Epoch 23/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9878 - loss: 0.0471 - val_accuracy: 0.9744 - val_loss: 0.0925 - learning_rate: 0.0010
# Epoch 24/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9834 - loss: 0.0529 - val_accuracy: 0.9789 - val_loss: 0.0998 - learning_rate: 0.0010
# Epoch 25/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9769 - loss: 0.0692 - val_accuracy: 0.9778 - val_loss: 0.0961 - learning_rate: 0.0010
# Epoch 26/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9785 - loss: 0.0604 - val_accuracy: 0.9711 - val_loss: 0.1037 - learning_rate: 0.0010
# Epoch 27/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9823 - loss: 0.0616 - val_accuracy: 0.9811 - val_loss: 0.1019 - learning_rate: 0.0010
# Epoch 28/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9825 - loss: 0.0494 - val_accuracy: 0.9789 - val_loss: 0.1068 - learning_rate: 5.0000e-04
# Epoch 29/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9868 - loss: 0.0396 - val_accuracy: 0.9789 - val_loss: 0.1003 - learning_rate: 5.0000e-04
# Epoch 30/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9918 - loss: 0.0356 - val_accuracy: 0.9800 - val_loss: 0.1004 - learning_rate: 5.0000e-04
# Epoch 31/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9857 - loss: 0.0404 - val_accuracy: 0.9800 - val_loss: 0.0987 - learning_rate: 5.0000e-04
# Epoch 32/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9881 - loss: 0.0364 - val_accuracy: 0.9778 - val_loss: 0.1006 - learning_rate: 5.0000e-04
#
# Базовая модель - Test Accuracy: 0.9840

# %%
print("RBM ПОДХОД ДЛЯ ПРЕДОБУЧЕНИЯ")
print("="*50)

class RBM:
    def __init__(self, n_visible, n_hidden, learning_rate=0.01, momentum=0.9):
        self.n_visible = n_visible
        self.n_hidden = n_hidden
        self.learning_rate = learning_rate
        self.momentum = momentum

        self.W = np.random.normal(0, 0.01, (n_visible, n_hidden))
        self.v_bias = np.zeros(n_visible)
        self.h_bias = np.zeros(n_hidden)

        self.W_inc = np.zeros((n_visible, n_hidden))
        self.v_bias_inc = np.zeros(n_visible)
        self.h_bias_inc = np.zeros(n_hidden)

    def sigmoid(self, x):
        return 1 / (1 + np.exp(-np.clip(x, -250, 250)))

    def sample_hidden(self, visible):
        activation = np.dot(visible, self.W) + self.h_bias
        p_hidden = self.sigmoid(activation)
        return p_hidden, np.random.binomial(1, p_hidden)

    def sample_visible(self, hidden):
        activation = np.dot(hidden, self.W.T) + self.v_bias
        p_visible = self.sigmoid(activation)
        return p_visible, np.random.binomial(1, p_visible)

    def contrastive_divergence(self, input_data, k=1):
        pos_hidden_probs, pos_hidden_states = self.sample_hidden(input_data)

        hidden_states = pos_hidden_states
        for _ in range(k):
            neg_visible_probs, neg_visible_states = self.sample_visible(hidden_states)
            neg_hidden_probs, neg_hidden_states = self.sample_hidden(neg_visible_states)
            hidden_states = neg_hidden_states

        positive_associations = np.dot(input_data.T, pos_hidden_probs)
        negative_associations = np.dot(neg_visible_states.T, neg_hidden_probs)

        self.W_inc = self.momentum * self.W_inc + \
                    self.learning_rate * ((positive_associations - negative_associations) / len(input_data))
        self.v_bias_inc = self.momentum * self.v_bias_inc + \
                         self.learning_rate * np.mean(input_data - neg_visible_states, axis=0)
        self.h_bias_inc = self.momentum * self.h_bias_inc + \
                         self.learning_rate * np.mean(pos_hidden_probs - neg_hidden_probs, axis=0)

        self.W += self.W_inc
        self.v_bias += self.v_bias_inc
        self.h_bias += self.h_bias_inc

        reconstruction_error = np.mean((input_data - neg_visible_probs) ** 2)
        return reconstruction_error

    def transform(self, data):
        hidden_probs, _ = self.sample_hidden(data)
        return hidden_probs

    def get_weights(self):
        return [self.W, self.h_bias]

print("Предобучение RBM...")

X_min = X_train_scaled.min()
X_max = X_train_scaled.max()
X_train_rbm = (X_train_scaled - X_min) / (X_max - X_min)
X_test_rbm = (X_test_scaled - X_min) / (X_max - X_min)

pretrained_weights_rbm = []

print("1. Обучение первого RBM слоя:")
rbm1 = RBM(n_visible=input_dim, n_hidden=128, learning_rate=0.01, momentum=0.9)

rbm1_errors = []
for epoch in range(100):
    error = rbm1.contrastive_divergence(X_train_rbm, k=1)
    rbm1_errors.append(error)
    if epoch % 20 == 0:
        print(f"   Epoch {epoch}, Reconstruction Error: {error:.4f}")

pretrained_weights_rbm.append(rbm1.get_weights())
hidden1_output = rbm1.transform(X_train_rbm)

print("2. Обучение второго RBM слоя:")
rbm2 = RBM(n_visible=128, n_hidden=64, learning_rate=0.01, momentum=0.9)

rbm2_errors = []
for epoch in range(100):
    error = rbm2.contrastive_divergence(hidden1_output, k=1)
    rbm2_errors.append(error)
    if epoch % 20 == 0:
        print(f"   Epoch {epoch}, Reconstruction Error: {error:.4f}")

pretrained_weights_rbm.append(rbm2.get_weights())
hidden2_output = rbm2.transform(hidden1_output)

print("3. Обучение третьего RBM слоя:")
rbm3 = RBM(n_visible=64, n_hidden=32, learning_rate=0.01, momentum=0.9)

rbm3_errors = []
for epoch in range(100):
    error = rbm3.contrastive_divergence(hidden2_output, k=1)
    rbm3_errors.append(error)
    if epoch % 20 == 0:
        print(f"   Epoch {epoch}, Reconstruction Error: {error:.4f}")

pretrained_weights_rbm.append(rbm3.get_weights())

print("Все RBM слои обучены!")

plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.plot(rbm1_errors, color='blue', linewidth=2)
plt.title('RBM 1 - Ошибки реконструкции')
plt.xlabel('Epoch')
plt.ylabel('Reconstruction Error')
plt.grid(True, alpha=0.3)

plt.subplot(1, 3, 2)
plt.plot(rbm2_errors, color='red', linewidth=2)
plt.title('RBM 2 - Ошибки реконструкции')
plt.xlabel('Epoch')
plt.ylabel('Reconstruction Error')
plt.grid(True, alpha=0.3)

plt.subplot(1, 3, 3)
plt.plot(rbm3_errors, color='green', linewidth=2)
plt.title('RBM 3 - Ошибки реконструкции')
plt.xlabel('Epoch')
plt.ylabel('Reconstruction Error')
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# RBM ПОДХОД ДЛЯ ПРЕДОБУЧЕНИЯ
# ==================================================
# Предобучение RBM...
# 1. Обучение первого RBM слоя:
#    Epoch 0, Reconstruction Error: 0.1986
#    Epoch 20, Reconstruction Error: 0.0017
#    Epoch 40, Reconstruction Error: 0.0008
#    Epoch 60, Reconstruction Error: 0.0007
#    Epoch 80, Reconstruction Error: 0.0005
# 2. Обучение второго RBM слоя:
#    Epoch 0, Reconstruction Error: 0.0037
#    Epoch 20, Reconstruction Error: 0.0004
#    Epoch 40, Reconstruction Error: 0.0002
#    Epoch 60, Reconstruction Error: 0.0001
#    Epoch 80, Reconstruction Error: 0.0001
# 3. Обучение третьего RBM слоя:
#    Epoch 0, Reconstruction Error: 0.0151
#    Epoch 20, Reconstruction Error: 0.0008
#    Epoch 40, Reconstruction Error: 0.0006
#    Epoch 60, Reconstruction Error: 0.0006
#    Epoch 80, Reconstruction Error: 0.0005
# Все RBM слои обучены!

# %%
print("СОЗДАНИЕ МОДЕЛИ С RBM ПРЕДОБУЧЕНИЕМ")
print("="*50)

pretrained_model_rbm = models.Sequential()
pretrained_model_rbm.add(layers.Dense(128, activation='sigmoid', input_shape=(input_dim,), name='pretrained_layer1'))
pretrained_model_rbm.add(layers.Dropout(0.3))
pretrained_model_rbm.add(layers.Dense(64, activation='sigmoid', name='pretrained_layer2'))
pretrained_model_rbm.add(layers.Dropout(0.3))
pretrained_model_rbm.add(layers.Dense(32, activation='sigmoid', name='pretrained_layer3'))
pretrained_model_rbm.add(layers.Dropout(0.2))
pretrained_model_rbm.add(layers.Dense(num_classes, activation='softmax', name='output_layer'))

print("Установка предобученных весов RBM...")
pretrained_model_rbm.layers[0].set_weights([pretrained_weights_rbm[0][0], pretrained_weights_rbm[0][1]])
pretrained_model_rbm.layers[2].set_weights([pretrained_weights_rbm[1][0], pretrained_weights_rbm[1][1]])
pretrained_model_rbm.layers[4].set_weights([pretrained_weights_rbm[2][0], pretrained_weights_rbm[2][1]])

pretrained_model_rbm.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

print("Архитектура модели с RBM предобучением:")
pretrained_model_rbm.summary()

print("ОБУЧЕНИЕ С УЧИТЕЛЕМ")
print("="*50)

history_pretrained_rbm = pretrained_model_rbm.fit(
    X_train_scaled, y_train,
    epochs=100,
    batch_size=32,
    validation_split=0.2,
    verbose=1,
    callbacks=[
        keras.callbacks.EarlyStopping(patience=15, restore_best_weights=True),
        keras.callbacks.ReduceLROnPlateau(patience=10, factor=0.5)
    ]
)

test_loss_rbm, test_accuracy_rbm = pretrained_model_rbm.evaluate(X_test_scaled, y_test, verbose=0)
print(f"\nМодель с RBM предобучением - Test Accuracy: {test_accuracy_rbm:.4f}")
# Out:
# СОЗДАНИЕ МОДЕЛИ С RBM ПРЕДОБУЧЕНИЕМ
# ==================================================
# Установка предобученных весов RBM...
# Архитектура модели с RBM предобучением:
# Model: "sequential_13"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ pretrained_layer1 (Dense)       │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pretrained_layer2 (Dense)       │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pretrained_layer3 (Dense)       │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 10)             │           330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 18,986 (74.16 KB)
#  Trainable params: 18,986 (74.16 KB)
#  Non-trainable params: 0 (0.00 B)
# ОБУЧЕНИЕ С УЧИТЕЛЕМ
# ==================================================
# Epoch 1/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1068 - loss: 2.3229 - val_accuracy: 0.1000 - val_loss: 2.2965 - learning_rate: 0.0010
# Epoch 2/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1168 - loss: 2.2878 - val_accuracy: 0.0922 - val_loss: 2.2567 - learning_rate: 0.0010
# Epoch 3/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1274 - loss: 2.2323 - val_accuracy: 0.1744 - val_loss: 2.1827 - learning_rate: 0.0010
# Epoch 4/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1674 - loss: 2.1413 - val_accuracy: 0.1811 - val_loss: 2.0657 - learning_rate: 0.0010
# Epoch 5/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1873 - loss: 2.0206 - val_accuracy: 0.2011 - val_loss: 1.9789 - learning_rate: 0.0010
# Epoch 6/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2099 - loss: 1.9552 - val_accuracy: 0.1967 - val_loss: 1.9223 - learning_rate: 0.0010
# Epoch 7/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2222 - loss: 1.8784 - val_accuracy: 0.2667 - val_loss: 1.8565 - learning_rate: 0.0010
# Epoch 8/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2593 - loss: 1.8024 - val_accuracy: 0.2811 - val_loss: 1.7749 - learning_rate: 0.0010
# Epoch 9/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2892 - loss: 1.7303 - val_accuracy: 0.2878 - val_loss: 1.7088 - learning_rate: 0.0010
# Epoch 10/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3033 - loss: 1.6596 - val_accuracy: 0.3478 - val_loss: 1.6489 - learning_rate: 0.0010
# Epoch 11/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3499 - loss: 1.6033 - val_accuracy: 0.3589 - val_loss: 1.5768 - learning_rate: 0.0010
# Epoch 12/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3813 - loss: 1.5211 - val_accuracy: 0.3711 - val_loss: 1.4756 - learning_rate: 0.0010
# Epoch 13/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4221 - loss: 1.4146 - val_accuracy: 0.4500 - val_loss: 1.3552 - learning_rate: 0.0010
# Epoch 14/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4640 - loss: 1.3180 - val_accuracy: 0.4856 - val_loss: 1.2669 - learning_rate: 0.0010
# Epoch 15/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4983 - loss: 1.2158 - val_accuracy: 0.5811 - val_loss: 1.1793 - learning_rate: 0.0010
# Epoch 16/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5262 - loss: 1.1435 - val_accuracy: 0.6411 - val_loss: 1.1124 - learning_rate: 0.0010
# Epoch 17/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5694 - loss: 1.0717 - val_accuracy: 0.6344 - val_loss: 1.0506 - learning_rate: 0.0010
# Epoch 18/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5840 - loss: 1.0180 - val_accuracy: 0.6711 - val_loss: 0.9477 - learning_rate: 0.0010
# Epoch 19/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6328 - loss: 0.9444 - val_accuracy: 0.7311 - val_loss: 0.8572 - learning_rate: 0.0010
# Epoch 20/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7101 - loss: 0.8432 - val_accuracy: 0.7567 - val_loss: 0.7718 - learning_rate: 0.0010
# Epoch 21/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7280 - loss: 0.7732 - val_accuracy: 0.7711 - val_loss: 0.7149 - learning_rate: 0.0010
# Epoch 22/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7512 - loss: 0.7184 - val_accuracy: 0.7956 - val_loss: 0.6678 - learning_rate: 0.0010
# Epoch 23/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7536 - loss: 0.7060 - val_accuracy: 0.7989 - val_loss: 0.6280 - learning_rate: 0.0010
# Epoch 24/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7707 - loss: 0.6487 - val_accuracy: 0.8267 - val_loss: 0.5955 - learning_rate: 0.0010
# Epoch 25/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7926 - loss: 0.6111 - val_accuracy: 0.8322 - val_loss: 0.5551 - learning_rate: 0.0010
# Epoch 26/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8067 - loss: 0.5973 - val_accuracy: 0.8378 - val_loss: 0.5248 - learning_rate: 0.0010
# Epoch 27/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8087 - loss: 0.5774 - val_accuracy: 0.8411 - val_loss: 0.4995 - learning_rate: 0.0010
# Epoch 28/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8262 - loss: 0.5352 - val_accuracy: 0.8400 - val_loss: 0.4923 - learning_rate: 0.0010
# Epoch 29/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8411 - loss: 0.5039 - val_accuracy: 0.8511 - val_loss: 0.4525 - learning_rate: 0.0010
# Epoch 30/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8416 - loss: 0.4626 - val_accuracy: 0.8556 - val_loss: 0.4402 - learning_rate: 0.0010
# Epoch 31/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8325 - loss: 0.4798 - val_accuracy: 0.8600 - val_loss: 0.4239 - learning_rate: 0.0010
# Epoch 32/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8459 - loss: 0.4756 - val_accuracy: 0.8644 - val_loss: 0.4123 - learning_rate: 0.0010
# Epoch 33/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8493 - loss: 0.4535 - val_accuracy: 0.8656 - val_loss: 0.3912 - learning_rate: 0.0010
# Epoch 34/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8693 - loss: 0.4097 - val_accuracy: 0.8811 - val_loss: 0.3673 - learning_rate: 0.0010
# Epoch 35/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8704 - loss: 0.3913 - val_accuracy: 0.8889 - val_loss: 0.3589 - learning_rate: 0.0010
# Epoch 36/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8770 - loss: 0.3886 - val_accuracy: 0.8989 - val_loss: 0.3360 - learning_rate: 0.0010
# Epoch 37/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8894 - loss: 0.3759 - val_accuracy: 0.9156 - val_loss: 0.3141 - learning_rate: 0.0010
# Epoch 38/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8962 - loss: 0.3517 - val_accuracy: 0.9333 - val_loss: 0.2919 - learning_rate: 0.0010
# Epoch 39/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8964 - loss: 0.3462 - val_accuracy: 0.9156 - val_loss: 0.2937 - learning_rate: 0.0010
# Epoch 40/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9119 - loss: 0.3064 - val_accuracy: 0.9378 - val_loss: 0.2721 - learning_rate: 0.0010
# Epoch 41/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9162 - loss: 0.3000 - val_accuracy: 0.9367 - val_loss: 0.2627 - learning_rate: 0.0010
# Epoch 42/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9115 - loss: 0.3155 - val_accuracy: 0.9367 - val_loss: 0.2638 - learning_rate: 0.0010
# Epoch 43/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9214 - loss: 0.2868 - val_accuracy: 0.9389 - val_loss: 0.2487 - learning_rate: 0.0010
# Epoch 44/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9251 - loss: 0.2819 - val_accuracy: 0.9433 - val_loss: 0.2449 - learning_rate: 0.0010
# Epoch 45/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9299 - loss: 0.2601 - val_accuracy: 0.9411 - val_loss: 0.2452 - learning_rate: 0.0010
# Epoch 46/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9301 - loss: 0.2634 - val_accuracy: 0.9422 - val_loss: 0.2373 - learning_rate: 0.0010
# Epoch 47/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9252 - loss: 0.2723 - val_accuracy: 0.9422 - val_loss: 0.2329 - learning_rate: 0.0010
# Epoch 48/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9300 - loss: 0.2701 - val_accuracy: 0.9422 - val_loss: 0.2390 - learning_rate: 0.0010
# Epoch 49/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9394 - loss: 0.2350 - val_accuracy: 0.9411 - val_loss: 0.2412 - learning_rate: 0.0010
# Epoch 50/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9302 - loss: 0.2385 - val_accuracy: 0.9456 - val_loss: 0.2341 - learning_rate: 0.0010
# Epoch 51/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9313 - loss: 0.2411 - val_accuracy: 0.9422 - val_loss: 0.2360 - learning_rate: 0.0010
# Epoch 52/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9396 - loss: 0.2169 - val_accuracy: 0.9456 - val_loss: 0.2255 - learning_rate: 0.0010
# Epoch 53/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9354 - loss: 0.2264 - val_accuracy: 0.9478 - val_loss: 0.2314 - learning_rate: 0.0010
# Epoch 54/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9442 - loss: 0.2264 - val_accuracy: 0.9478 - val_loss: 0.2315 - learning_rate: 0.0010
# Epoch 55/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9457 - loss: 0.1985 - val_accuracy: 0.9478 - val_loss: 0.2160 - learning_rate: 0.0010
# Epoch 56/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9418 - loss: 0.2046 - val_accuracy: 0.9478 - val_loss: 0.2241 - learning_rate: 0.0010
# Epoch 57/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9421 - loss: 0.2155 - val_accuracy: 0.9433 - val_loss: 0.2110 - learning_rate: 0.0010
# Epoch 58/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9436 - loss: 0.1929 - val_accuracy: 0.9478 - val_loss: 0.2075 - learning_rate: 0.0010
# Epoch 59/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9505 - loss: 0.1916 - val_accuracy: 0.9478 - val_loss: 0.2064 - learning_rate: 0.0010
# Epoch 60/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9515 - loss: 0.1763 - val_accuracy: 0.9500 - val_loss: 0.2000 - learning_rate: 0.0010
# Epoch 61/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9557 - loss: 0.1677 - val_accuracy: 0.9511 - val_loss: 0.2035 - learning_rate: 0.0010
# Epoch 62/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9530 - loss: 0.1979 - val_accuracy: 0.9500 - val_loss: 0.2019 - learning_rate: 0.0010
# Epoch 63/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9517 - loss: 0.1932 - val_accuracy: 0.9511 - val_loss: 0.1970 - learning_rate: 0.0010
# Epoch 64/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9484 - loss: 0.1837 - val_accuracy: 0.9500 - val_loss: 0.1996 - learning_rate: 0.0010
# Epoch 65/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9567 - loss: 0.1611 - val_accuracy: 0.9533 - val_loss: 0.1940 - learning_rate: 0.0010
# Epoch 66/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9572 - loss: 0.1590 - val_accuracy: 0.9511 - val_loss: 0.1952 - learning_rate: 0.0010
# Epoch 67/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9474 - loss: 0.1810 - val_accuracy: 0.9567 - val_loss: 0.1890 - learning_rate: 0.0010
# Epoch 68/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9482 - loss: 0.1865 - val_accuracy: 0.9544 - val_loss: 0.1935 - learning_rate: 0.0010
# Epoch 69/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9502 - loss: 0.1824 - val_accuracy: 0.9544 - val_loss: 0.1960 - learning_rate: 0.0010
# Epoch 70/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9572 - loss: 0.1503 - val_accuracy: 0.9533 - val_loss: 0.1995 - learning_rate: 0.0010
# Epoch 71/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9573 - loss: 0.1570 - val_accuracy: 0.9544 - val_loss: 0.1977 - learning_rate: 0.0010
# Epoch 72/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9549 - loss: 0.1615 - val_accuracy: 0.9533 - val_loss: 0.1897 - learning_rate: 0.0010
# Epoch 73/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9523 - loss: 0.1608 - val_accuracy: 0.9556 - val_loss: 0.1897 - learning_rate: 0.0010
# Epoch 74/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9557 - loss: 0.1666 - val_accuracy: 0.9556 - val_loss: 0.1859 - learning_rate: 0.0010
# Epoch 75/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9600 - loss: 0.1399 - val_accuracy: 0.9556 - val_loss: 0.1903 - learning_rate: 0.0010
# Epoch 76/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9607 - loss: 0.1488 - val_accuracy: 0.9556 - val_loss: 0.1914 - learning_rate: 0.0010
# Epoch 77/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9616 - loss: 0.1489 - val_accuracy: 0.9556 - val_loss: 0.1832 - learning_rate: 0.0010
# Epoch 78/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9633 - loss: 0.1298 - val_accuracy: 0.9533 - val_loss: 0.1858 - learning_rate: 0.0010
# Epoch 79/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9505 - loss: 0.1559 - val_accuracy: 0.9589 - val_loss: 0.1833 - learning_rate: 0.0010
# Epoch 80/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9632 - loss: 0.1247 - val_accuracy: 0.9544 - val_loss: 0.1794 - learning_rate: 0.0010
# Epoch 81/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9543 - loss: 0.1513 - val_accuracy: 0.9556 - val_loss: 0.1844 - learning_rate: 0.0010
# Epoch 82/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9630 - loss: 0.1328 - val_accuracy: 0.9578 - val_loss: 0.1853 - learning_rate: 0.0010
# Epoch 83/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9648 - loss: 0.1266 - val_accuracy: 0.9600 - val_loss: 0.1777 - learning_rate: 0.0010
# Epoch 84/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9624 - loss: 0.1381 - val_accuracy: 0.9600 - val_loss: 0.1830 - learning_rate: 0.0010
# Epoch 85/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9584 - loss: 0.1492 - val_accuracy: 0.9578 - val_loss: 0.1791 - learning_rate: 0.0010
# Epoch 86/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9609 - loss: 0.1430 - val_accuracy: 0.9600 - val_loss: 0.1762 - learning_rate: 0.0010
# Epoch 87/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9618 - loss: 0.1291 - val_accuracy: 0.9589 - val_loss: 0.1733 - learning_rate: 0.0010
# Epoch 88/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9637 - loss: 0.1305 - val_accuracy: 0.9556 - val_loss: 0.1745 - learning_rate: 0.0010
# Epoch 89/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9716 - loss: 0.1073 - val_accuracy: 0.9578 - val_loss: 0.1782 - learning_rate: 0.0010
# Epoch 90/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9655 - loss: 0.1254 - val_accuracy: 0.9622 - val_loss: 0.1702 - learning_rate: 0.0010
# Epoch 91/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9679 - loss: 0.1092 - val_accuracy: 0.9589 - val_loss: 0.1725 - learning_rate: 0.0010
# Epoch 92/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9715 - loss: 0.1073 - val_accuracy: 0.9622 - val_loss: 0.1718 - learning_rate: 0.0010
# Epoch 93/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9668 - loss: 0.1292 - val_accuracy: 0.9600 - val_loss: 0.1723 - learning_rate: 0.0010
# Epoch 94/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9707 - loss: 0.1100 - val_accuracy: 0.9589 - val_loss: 0.1673 - learning_rate: 0.0010
# Epoch 95/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9669 - loss: 0.1143 - val_accuracy: 0.9622 - val_loss: 0.1647 - learning_rate: 0.0010
# Epoch 96/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9705 - loss: 0.1093 - val_accuracy: 0.9589 - val_loss: 0.1644 - learning_rate: 0.0010
# Epoch 97/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9735 - loss: 0.0990 - val_accuracy: 0.9622 - val_loss: 0.1672 - learning_rate: 0.0010
# Epoch 98/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9757 - loss: 0.1011 - val_accuracy: 0.9622 - val_loss: 0.1675 - learning_rate: 0.0010
# Epoch 99/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9710 - loss: 0.1148 - val_accuracy: 0.9611 - val_loss: 0.1724 - learning_rate: 0.0010
# Epoch 100/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9761 - loss: 0.0966 - val_accuracy: 0.9589 - val_loss: 0.1700 - learning_rate: 0.0010
#
# Модель с RBM предобучением - Test Accuracy: 0.9653

# %%
print("ВИЗУАЛИЗАЦИЯ ПРОЦЕССА ОБУЧЕНИЯ")
print("="*50)

plt.figure(figsize=(15, 10))

plt.subplot(2, 3, 1)
min_epochs = min(len(history_base.history['val_accuracy']),
                 len(history_pretrained_rbm.history['val_accuracy']))
epochs_range = range(min_epochs)

plt.plot(epochs_range, history_base.history['val_accuracy'][:min_epochs],
         label='Базовая модель', linewidth=2, color='blue')
plt.plot(epochs_range, history_pretrained_rbm.history['val_accuracy'][:min_epochs],
         label='RBM предобучение', linewidth=2, color='green')
plt.title('Сравнение валидационной точности', fontsize=14, fontweight='bold')
plt.xlabel('Epoch')
plt.ylabel('Validation Accuracy')
plt.legend()
plt.grid(True, alpha=0.3)

plt.subplot(2, 3, 2)
plt.plot(epochs_range, history_base.history['val_loss'][:min_epochs],
         label='Базовая модель', linewidth=2, color='blue')
plt.plot(epochs_range, history_pretrained_rbm.history['val_loss'][:min_epochs],
         label='RBM предобучение', linewidth=2, color='green')
plt.title('Сравнение валидационных потерь', fontsize=14, fontweight='bold')
plt.xlabel('Epoch')
plt.ylabel('Validation Loss')
plt.legend()
plt.grid(True, alpha=0.3)

plt.subplot(2, 3, 3)
plt.plot(history_base.history['accuracy'], label='Базовая модель', linewidth=2, color='blue', alpha=0.7)
plt.plot(history_pretrained_rbm.history['accuracy'], label='RBM предобучение', linewidth=2, color='green', alpha=0.7)
plt.title('Точность на обучающей выборке', fontsize=14, fontweight='bold')
plt.xlabel('Epoch')
plt.ylabel('Training Accuracy')
plt.legend()
plt.grid(True, alpha=0.3)

plt.subplot(2, 3, 4)
plt.plot(history_base.history['loss'], label='Базовая модель', linewidth=2, color='blue', alpha=0.7)
plt.plot(history_pretrained_rbm.history['loss'], label='RBM предобучение', linewidth=2, color='green', alpha=0.7)
plt.title('Потери на обучающей выборке', fontsize=14, fontweight='bold')
plt.xlabel('Epoch')
plt.ylabel('Training Loss')
plt.legend()
plt.grid(True, alpha=0.3)

plt.subplot(2, 3, 5)
models_names = ['Базовая модель', 'RBM предобучение']
accuracies = [test_accuracy_base, test_accuracy_rbm]
colors = ['skyblue', 'lightgreen']
bars = plt.bar(models_names, accuracies, color=colors, alpha=0.8)
plt.title('Сравнение итоговой точности', fontsize=14, fontweight='bold')
plt.ylabel('Test Accuracy')
plt.ylim(0, 1)
for bar, acc in zip(bars, accuracies):
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.01,
             f'{acc:.4f}', ha='center', va='bottom', fontweight='bold')

plt.subplot(2, 3, 6)
improvement = (test_accuracy_rbm - test_accuracy_base) * 100
colors_imp = ['red' if improvement < 0 else 'green']
plt.bar(['Улучшение'], [improvement], color=colors_imp, alpha=0.8)
plt.title('Улучшение точности RBM', fontsize=14, fontweight='bold')
plt.ylabel('Improvement (%)')
plt.axhline(y=0, color='black', linestyle='-', alpha=0.3)
plt.text(0, improvement + (1 if improvement > 0 else -1),
         f'{improvement:+.2f}%', ha='center', va='bottom' if improvement > 0 else 'top',
         fontweight='bold', fontsize=12)

plt.tight_layout()
plt.show()
# Out:
# ВИЗУАЛИЗАЦИЯ ПРОЦЕССА ОБУЧЕНИЯ
# ==================================================

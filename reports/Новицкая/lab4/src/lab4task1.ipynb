# %%
# !pip install tensorflow
# !pip install scikit-learn

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
import warnings
import os

warnings.filterwarnings('ignore')

file_path = 'CASP.csv'

if os.path.exists(file_path):
    print(f"Загрузка файла из: {file_path}")
    data = pd.read_csv(file_path)
else:
    raise FileNotFoundError(f"Файл не найден по пути: {file_path}. Пожалуйста, убедитесь, что имя файла верное.")

y = data[['RMSD']]
X = data.drop(['RMSD'], axis=1)

print("Информация о датасете Protein Tertiary Structure:")
print(f"Размерность признаков (X): {X.shape}")
print(f"Размерность целевой переменной (y): {y.shape}")

print("\nНазвания признаков:")
print(X.columns.tolist())

print("\nНазвания целевых переменных:")
print(y.columns.tolist())

print("\nСтатистика целевой переменной 'RMSD':")
print(y['RMSD'].describe())

print("\nПервые 5 строк признаков:")
print(X.head())

print("\nПервые 5 строк целевой переменной:")
print(y.head())

print(f"\nПропущенные значения в X: {X.isnull().sum().sum()}")
print(f"Пропущенные значения в y: {y.isnull().sum().sum()}")
print("Типы данных в признаках:")
print(X.dtypes)

X_processed = X.copy()

if X_processed.isnull().sum().sum() > 0:
    print("Заполняем пропущенные значения...")
    X_processed = X_processed.fillna(X_processed.mean())

y_target = y['RMSD'].values
y_target_log = np.log1p(y_target)

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.hist(y_target, bins=50, alpha=0.7, color='red', edgecolor='black')
plt.title('Распределение целевой переменной (RMSD)')
plt.xlabel('RMSD')
plt.ylabel('Частота')
plt.grid(True, alpha=0.3)

plt.subplot(1, 2, 2)
plt.hist(y_target_log, bins=50, alpha=0.7, color='green', edgecolor='black')
plt.title('Распределение log(1+RMSD)')
plt.xlabel('log(1+RMSD)')
plt.ylabel('Частота')
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

X_train, X_test, y_train, y_test = train_test_split(
    X_processed, y_target_log, test_size=0.2, random_state=42
)

scaler_X = StandardScaler()
X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.transform(X_test)

print(f"\nРазмер train выборки: {X_train_scaled.shape}")
print(f"Размер test выборки: {X_test_scaled.shape}")
print(f"Количество признаков: {X_train_scaled.shape[1]}")

class RBM:
    def __init__(self, n_visible, n_hidden, learning_rate=0.01, momentum=0.9):
        self.n_visible = n_visible
        self.n_hidden = n_hidden
        self.learning_rate = learning_rate
        self.momentum = momentum

        self.W = np.random.normal(0, 0.01, (n_visible, n_hidden))
        self.v_bias = np.zeros(n_visible)
        self.h_bias = np.zeros(n_hidden)

        self.W_inc = np.zeros((n_visible, n_hidden))
        self.v_bias_inc = np.zeros(n_visible)
        self.h_bias_inc = np.zeros(n_hidden)

    def sigmoid(self, x):
        return 1 / (1 + np.exp(-np.clip(x, -250, 250)))

    def sample_hidden(self, visible):
        activation = np.dot(visible, self.W) + self.h_bias
        p_hidden = self.sigmoid(activation)
        return p_hidden, np.random.binomial(1, p_hidden)

    def sample_visible(self, hidden):
        activation = np.dot(hidden, self.W.T) + self.v_bias
        p_visible = self.sigmoid(activation)
        return p_visible, np.random.binomial(1, p_visible)

    def contrastive_divergence(self, input_data, k=1):
        pos_hidden_probs, pos_hidden_states = self.sample_hidden(input_data)
        hidden_states = pos_hidden_states
        for _ in range(k):
            neg_visible_probs, neg_visible_states = self.sample_visible(hidden_states)
            neg_hidden_probs, neg_hidden_states = self.sample_hidden(neg_visible_states)
            hidden_states = neg_hidden_states

        positive_associations = np.dot(input_data.T, pos_hidden_probs)
        negative_associations = np.dot(neg_visible_states.T, neg_hidden_probs)

        self.W_inc = self.momentum * self.W_inc + \
                    self.learning_rate * ((positive_associations - negative_associations) / len(input_data))
        self.v_bias_inc = self.momentum * self.v_bias_inc + \
                         self.learning_rate * np.mean(input_data - neg_visible_states, axis=0)
        self.h_bias_inc = self.momentum * self.h_bias_inc + \
                         self.learning_rate * np.mean(pos_hidden_probs - neg_hidden_probs, axis=0)

        self.W += self.W_inc
        self.v_bias += self.v_bias_inc
        self.h_bias += self.h_bias_inc

        reconstruction_error = np.mean((input_data - neg_visible_probs) ** 2)
        return reconstruction_error

    def transform(self, data):
        hidden_probs, _ = self.sample_hidden(data)
        return hidden_probs

    def get_weights(self):
        return [self.W, self.h_bias]

X_min = X_train_scaled.min()
X_max = X_train_scaled.max()
X_train_rbm = (X_train_scaled - X_min) / (X_max - X_min)
X_test_rbm = (X_test_scaled - X_min) / (X_max - X_min)

input_dim = X_train_scaled.shape[1]
pretrained_weights_rbm = []

print(f"Размерность входных данных: {input_dim}")

print("\n1. Обучение первого RBM слоя (128 нейронов):")
rbm1 = RBM(n_visible=input_dim, n_hidden=128, learning_rate=0.01, momentum=0.9)

rbm1_errors = []
for epoch in range(50):
    error = rbm1.contrastive_divergence(X_train_rbm, k=1)
    rbm1_errors.append(error)
    if epoch % 10 == 0:
        print(f"   Epoch {epoch}, Reconstruction Error: {error:.4f}")

pretrained_weights_rbm.append(rbm1.get_weights())
hidden1_output = rbm1.transform(X_train_rbm)

print("\n2. Обучение второго RBM слоя (64 нейрона):")
rbm2 = RBM(n_visible=128, n_hidden=64, learning_rate=0.01, momentum=0.9)

rbm2_errors = []
for epoch in range(50):
    error = rbm2.contrastive_divergence(hidden1_output, k=1)
    rbm2_errors.append(error)
    if epoch % 10 == 0:
        print(f"   Epoch {epoch}, Reconstruction Error: {error:.4f}")

pretrained_weights_rbm.append(rbm2.get_weights())
hidden2_output = rbm2.transform(hidden1_output)

print("\n3. Обучение третьего RBM слоя (32 нейрона):")
rbm3 = RBM(n_visible=64, n_hidden=32, learning_rate=0.01, momentum=0.9)

rbm3_errors = []
for epoch in range(50):
    error = rbm3.contrastive_divergence(hidden2_output, k=1)
    rbm3_errors.append(error)
    if epoch % 10 == 0:
        print(f"   Epoch {epoch}, Reconstruction Error: {error:.4f}")

pretrained_weights_rbm.append(rbm3.get_weights())


pretrained_model_rbm = models.Sequential()
pretrained_model_rbm.add(layers.Dense(128, activation='sigmoid', input_shape=(input_dim,), name='pretrained_layer1'))
pretrained_model_rbm.add(layers.Dropout(0.3))
pretrained_model_rbm.add(layers.Dense(64, activation='sigmoid', name='pretrained_layer2'))
pretrained_model_rbm.add(layers.Dropout(0.3))
pretrained_model_rbm.add(layers.Dense(32, activation='sigmoid', name='pretrained_layer3'))
pretrained_model_rbm.add(layers.Dropout(0.2))
pretrained_model_rbm.add(layers.Dense(1, activation='linear', name='output_layer'))

pretrained_model_rbm.layers[0].set_weights([pretrained_weights_rbm[0][0], pretrained_weights_rbm[0][1]])
pretrained_model_rbm.layers[2].set_weights([pretrained_weights_rbm[1][0], pretrained_weights_rbm[1][1]])
pretrained_model_rbm.layers[4].set_weights([pretrained_weights_rbm[2][0], pretrained_weights_rbm[2][1]])

pretrained_model_rbm.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss='mse',
    metrics=['mae']
)

pretrained_model_rbm.summary()

history_pretrained_rbm = pretrained_model_rbm.fit(
    X_train_scaled, y_train,
    epochs=100,
    batch_size=32,
    validation_split=0.2,
    verbose=1,
    callbacks=[
        keras.callbacks.EarlyStopping(patience=15, restore_best_weights=True),
        keras.callbacks.ReduceLROnPlateau(patience=10, factor=0.5)
    ]
)

def create_base_model(input_dim):
    model = models.Sequential([
        layers.Dense(128, activation='relu', input_shape=(input_dim,)),
        layers.Dropout(0.3),
        layers.Dense(64, activation='relu'),
        layers.Dropout(0.3),
        layers.Dense(32, activation='relu'),
        layers.Dropout(0.2),
        layers.Dense(1, activation='linear')
    ])
    return model

base_model = create_base_model(input_dim)
base_model.compile(
    optimizer='adam',
    loss='mse',
    metrics=['mae']
)

base_model.summary()
history_base = base_model.fit(
    X_train_scaled, y_train,
    epochs=100,
    batch_size=32,
    validation_split=0.2,
    verbose=1,
    callbacks=[
        keras.callbacks.EarlyStopping(patience=15, restore_best_weights=True),
        keras.callbacks.ReduceLROnPlateau(patience=10, factor=0.5)
    ]
)

def evaluate_regression_model(model, X_test, y_test_log, model_name):
    y_pred_log = model.predict(X_test, verbose=0).flatten()
    y_pred = np.expm1(y_pred_log) # Обратное преобразование log1p
    y_true = np.expm1(y_test_log)

    mse = mean_squared_error(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_true, y_pred)

    print(f"\n{model_name}:")
    print(f"MSE: {mse:.4f}")
    print(f"MAE: {mae:.4f}")
    print(f"RMSE: {rmse:.4f}")
    print(f"R² Score: {r2:.4f}")

    return mse, mae, rmse, r2, y_pred

mse_base, mae_base, rmse_base, r2_base, y_pred_base = evaluate_regression_model(
    base_model, X_test_scaled, y_test, "БАЗОВАЯ МОДЕЛЬ")

mse_rbm, mae_rbm, rmse_rbm, r2_rbm, y_pred_rbm = evaluate_regression_model(
    pretrained_model_rbm, X_test_scaled, y_test, "МОДЕЛЬ С RBM")

improvement_mse = ((mse_base - mse_rbm) / mse_base) * 100
improvement_mae = ((mae_base - mae_rbm) / mae_base) * 100
improvement_rmse = ((rmse_base - rmse_rbm) / rmse_base) * 100
improvement_r2 = (r2_rbm - r2_base) * 100

print(f"\nУЛУЧШЕНИЕ RBM МОДЕЛИ ОТНОСИТЕЛЬНО БАЗОВОЙ:")
print(f"MSE: {improvement_mse:+.2f}%")
print(f"MAE: {improvement_mae:+.2f}%")
print(f"RMSE: {improvement_rmse:+.2f}%")
print(f"R²: {improvement_r2:+.2f}%")


plt.figure(figsize=(20, 12))
plt.subplot(2, 3, 1)
metrics = ['MSE', 'MAE', 'RMSE']
base_scores = [mse_base, mae_base, rmse_base]
rbm_scores = [mse_rbm, mae_rbm, rmse_rbm]

x = np.arange(len(metrics))
width = 0.35

plt.bar(x - width/2, base_scores, width, label='Базовая модель', alpha=0.8)
plt.bar(x + width/2, rbm_scores, width, label='RBM модель', alpha=0.8)

plt.title('Сравнение метрик регрессии', fontsize=14, fontweight='bold')
plt.xlabel('Метрики')
plt.ylabel('Значение')
plt.xticks(x, metrics)
plt.legend()
plt.grid(True, alpha=0.3)

plt.subplot(2, 3, 2)
models_names = ['Базовая', 'RBM']
r2_scores = [r2_base, r2_rbm]
colors = ['skyblue', 'lightcoral']

bars = plt.bar(models_names, r2_scores, color=colors, alpha=0.8)
plt.title('Сравнение R² Score', fontsize=14, fontweight='bold')
plt.ylabel('R² Score')
plt.ylim(0, 1)
for bar, r2 in zip(bars, r2_scores):
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.01,
             f'{r2:.4f}', ha='center', va='bottom', fontweight='bold')

plt.subplot(2, 3, 3)
min_epochs = min(len(history_base.history['val_loss']),
                 len(history_pretrained_rbm.history['val_loss']))
epochs_range = range(min_epochs)

plt.plot(epochs_range, history_base.history['val_loss'][:min_epochs],
         label='Базовая модель', linewidth=2)
plt.plot(epochs_range, history_pretrained_rbm.history['val_loss'][:min_epochs],
         label='RBM модель', linewidth=2)
plt.title('Валидационные потери во время обучения', fontsize=14, fontweight='bold')
plt.xlabel('Epoch')
plt.ylabel('Validation Loss (MSE)')
plt.legend()
plt.grid(True, alpha=0.3)

plt.subplot(2, 3, 4)
plt.plot(rbm1_errors, label='RBM 1 (128 нейронов)', linewidth=2)
plt.plot(rbm2_errors, label='RBM 2 (64 нейрона)', linewidth=2)
plt.plot(rbm3_errors, label='RBM 3 (32 нейрона)', linewidth=2)
plt.title('Ошибки реконструкции RBM', fontsize=14, fontweight='bold')
plt.xlabel('Epoch')
plt.ylabel('Reconstruction Error')
plt.legend()
plt.grid(True, alpha=0.3)

plt.subplot(2, 3, 5)
y_true = np.expm1(y_test)
plt.scatter(y_true, y_pred_rbm, alpha=0.6, color='red')
plt.plot([y_true.min(), y_true.max()], [y_true.min(), y_true.max()], 'k--', lw=2)
plt.title('RBM модель: Предсказания vs Факт', fontsize=14, fontweight='bold')
plt.xlabel('Фактические значения (RMSD)')
plt.ylabel('Предсказанные значения (RMSD)')
plt.grid(True, alpha=0.3)

plt.subplot(2, 3, 6)
plt.scatter(y_true, y_pred_base, alpha=0.6, color='blue')
plt.plot([y_true.min(), y_true.max()], [y_true.min(), y_true.max()], 'k--', lw=2)
plt.title('Базовая модель: Предсказания vs Факт', fontsize=14, fontweight='bold')
plt.xlabel('Фактические значения (RMSD)')
plt.ylabel('Предсканные значения (RMSD)')
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.18.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.10)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.1.4)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Загрузка файла из: CASP.csv
# Информация о датасете Protein Tertiary Structure:
# Размерность признаков (X): (45730, 9)
# Размерность целевой переменной (y): (45730, 1)
#
# Названия признаков:
# ['F1', 'F2', 'F3', 'F4', 'F5', 'F6', 'F7', 'F8', 'F9']
#
# Названия целевых переменных:
# ['RMSD']
#
# Статистика целевой переменной 'RMSD':
# count    45730.000000
# mean         7.748528
# std          6.118312
# min          0.000000
# 25%          2.305000
# 50%          5.030000
# 75%         13.379000
# max         20.999000
# Name: RMSD, dtype: float64
#
# Первые 5 строк признаков:
#          F1       F2       F3        F4            F5        F6       F7   F8  \
# 0  13558.30  4305.35  0.31754  162.1730  1.872791e+06  215.3590  4287.87  102
# 1   6191.96  1623.16  0.26213   53.3894  8.034467e+05   87.2024  3328.91   39
# 2   7725.98  1726.28  0.22343   67.2887  1.075648e+06   81.7913  2981.04   29
# 3   8424.58  2368.25  0.28111   67.8325  1.210472e+06  109.4390  3248.22   70
# 4   7460.84  1736.94  0.23280   52.4123  1.021020e+06   94.5234  2814.42   41
#
#         F9
# 0  27.0302
# 1  38.5468
# 2  38.8119
# 3  39.0651
# 4  39.9147
#
# Первые 5 строк целевой переменной:
#      RMSD
# 0  17.284
# 1   6.021
# 2   9.275
# 3  15.851
# 4   7.962
#
# Пропущенные значения в X: 0
# Пропущенные значения в y: 0
# Типы данных в признаках:
# F1    float64
# F2    float64
# F3    float64
# F4    float64
# F5    float64
# F6    float64
# F7    float64
# F8      int64
# F9    float64
# dtype: object
# Размер train выборки: (36584, 9)
# Размер test выборки: (9146, 9)
# Количество признаков: 9
# Размерность входных данных: 9
#
# 1. Обучение первого RBM слоя (128 нейронов):
#    Epoch 0, Reconstruction Error: 0.1937
#    Epoch 10, Reconstruction Error: 0.0008
#    Epoch 20, Reconstruction Error: 0.0024
#    Epoch 30, Reconstruction Error: 0.0018
#    Epoch 40, Reconstruction Error: 0.0006
#
# 2. Обучение второго RBM слоя (64 нейрона):
#    Epoch 0, Reconstruction Error: 0.0003
#    Epoch 10, Reconstruction Error: 0.0001
#    Epoch 20, Reconstruction Error: 0.0001
#    Epoch 30, Reconstruction Error: 0.0001
#    Epoch 40, Reconstruction Error: 0.0001
#
# 3. Обучение третьего RBM слоя (32 нейрона):
#    Epoch 0, Reconstruction Error: 0.0004
#    Epoch 10, Reconstruction Error: 0.0001
#    Epoch 20, Reconstruction Error: 0.0001
#    Epoch 30, Reconstruction Error: 0.0001
#    Epoch 40, Reconstruction Error: 0.0000
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ pretrained_layer1 (Dense)       │ (None, 128)            │         1,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pretrained_layer2 (Dense)       │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pretrained_layer3 (Dense)       │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,649 (45.50 KB)
#  Trainable params: 11,649 (45.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 0.7794 - mae: 0.7444 - val_loss: 0.5283 - val_mae: 0.6458 - learning_rate: 0.0010
# Epoch 2/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.5717 - mae: 0.6439 - val_loss: 0.4514 - val_mae: 0.5726 - learning_rate: 0.0010
# Epoch 3/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.5136 - mae: 0.6000 - val_loss: 0.4330 - val_mae: 0.5585 - learning_rate: 0.0010
# Epoch 4/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.4778 - mae: 0.5731 - val_loss: 0.4308 - val_mae: 0.5533 - learning_rate: 0.0010
# Epoch 5/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4748 - mae: 0.5714 - val_loss: 0.4183 - val_mae: 0.5369 - learning_rate: 0.0010
# Epoch 6/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4694 - mae: 0.5669 - val_loss: 0.4185 - val_mae: 0.5426 - learning_rate: 0.0010
# Epoch 7/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4480 - mae: 0.5534 - val_loss: 0.4172 - val_mae: 0.5414 - learning_rate: 0.0010
# Epoch 8/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4409 - mae: 0.5496 - val_loss: 0.4109 - val_mae: 0.5301 - learning_rate: 0.0010
# Epoch 9/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4400 - mae: 0.5490 - val_loss: 0.4100 - val_mae: 0.5309 - learning_rate: 0.0010
# Epoch 10/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.4348 - mae: 0.5444 - val_loss: 0.4062 - val_mae: 0.5267 - learning_rate: 0.0010
# Epoch 11/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4272 - mae: 0.5393 - val_loss: 0.4059 - val_mae: 0.5279 - learning_rate: 0.0010
# Epoch 12/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4296 - mae: 0.5434 - val_loss: 0.4037 - val_mae: 0.5227 - learning_rate: 0.0010
# Epoch 13/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4273 - mae: 0.5415 - val_loss: 0.4027 - val_mae: 0.5252 - learning_rate: 0.0010
# Epoch 14/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4193 - mae: 0.5360 - val_loss: 0.4013 - val_mae: 0.5259 - learning_rate: 0.0010
# Epoch 15/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4200 - mae: 0.5362 - val_loss: 0.4000 - val_mae: 0.5230 - learning_rate: 0.0010
# Epoch 16/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4112 - mae: 0.5290 - val_loss: 0.4001 - val_mae: 0.5232 - learning_rate: 0.0010
# Epoch 17/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4165 - mae: 0.5345 - val_loss: 0.3980 - val_mae: 0.5228 - learning_rate: 0.0010
# Epoch 18/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4122 - mae: 0.5302 - val_loss: 0.3989 - val_mae: 0.5242 - learning_rate: 0.0010
# Epoch 19/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.4105 - mae: 0.5288 - val_loss: 0.3983 - val_mae: 0.5214 - learning_rate: 0.0010
# Epoch 20/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4126 - mae: 0.5325 - val_loss: 0.3947 - val_mae: 0.5191 - learning_rate: 0.0010
# Epoch 21/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4040 - mae: 0.5238 - val_loss: 0.3945 - val_mae: 0.5131 - learning_rate: 0.0010
# Epoch 22/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4032 - mae: 0.5222 - val_loss: 0.3958 - val_mae: 0.5238 - learning_rate: 0.0010
# Epoch 23/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.4030 - mae: 0.5233 - val_loss: 0.3958 - val_mae: 0.5222 - learning_rate: 0.0010
# Epoch 24/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4089 - mae: 0.5282 - val_loss: 0.3907 - val_mae: 0.5095 - learning_rate: 0.0010
# Epoch 25/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4060 - mae: 0.5254 - val_loss: 0.3908 - val_mae: 0.5141 - learning_rate: 0.0010
# Epoch 26/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4008 - mae: 0.5218 - val_loss: 0.3886 - val_mae: 0.5110 - learning_rate: 0.0010
# Epoch 27/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3996 - mae: 0.5194 - val_loss: 0.3923 - val_mae: 0.5197 - learning_rate: 0.0010
# Epoch 28/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4039 - mae: 0.5246 - val_loss: 0.3888 - val_mae: 0.5107 - learning_rate: 0.0010
# Epoch 29/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3999 - mae: 0.5197 - val_loss: 0.3908 - val_mae: 0.5210 - learning_rate: 0.0010
# Epoch 30/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3979 - mae: 0.5196 - val_loss: 0.3873 - val_mae: 0.5138 - learning_rate: 0.0010
# Epoch 31/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3912 - mae: 0.5127 - val_loss: 0.3860 - val_mae: 0.5106 - learning_rate: 0.0010
# Epoch 32/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.3972 - mae: 0.5177 - val_loss: 0.3845 - val_mae: 0.5084 - learning_rate: 0.0010
# Epoch 33/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4007 - mae: 0.5202 - val_loss: 0.3826 - val_mae: 0.5042 - learning_rate: 0.0010
# Epoch 34/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3928 - mae: 0.5151 - val_loss: 0.3811 - val_mae: 0.5020 - learning_rate: 0.0010
# Epoch 35/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.3963 - mae: 0.5167 - val_loss: 0.3808 - val_mae: 0.5072 - learning_rate: 0.0010
# Epoch 36/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3935 - mae: 0.5146 - val_loss: 0.3815 - val_mae: 0.5072 - learning_rate: 0.0010
# Epoch 37/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3922 - mae: 0.5134 - val_loss: 0.3809 - val_mae: 0.5099 - learning_rate: 0.0010
# Epoch 38/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3954 - mae: 0.5145 - val_loss: 0.3788 - val_mae: 0.5055 - learning_rate: 0.0010
# Epoch 39/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3922 - mae: 0.5139 - val_loss: 0.3768 - val_mae: 0.5032 - learning_rate: 0.0010
# Epoch 40/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3966 - mae: 0.5172 - val_loss: 0.3757 - val_mae: 0.5016 - learning_rate: 0.0010
# Epoch 41/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3891 - mae: 0.5109 - val_loss: 0.3756 - val_mae: 0.5027 - learning_rate: 0.0010
# Epoch 42/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3951 - mae: 0.5154 - val_loss: 0.3739 - val_mae: 0.4935 - learning_rate: 0.0010
# Epoch 43/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3872 - mae: 0.5079 - val_loss: 0.3749 - val_mae: 0.5005 - learning_rate: 0.0010
# Epoch 44/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.3871 - mae: 0.5105 - val_loss: 0.3734 - val_mae: 0.4960 - learning_rate: 0.0010
# Epoch 45/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3878 - mae: 0.5107 - val_loss: 0.3720 - val_mae: 0.4972 - learning_rate: 0.0010
# Epoch 46/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3873 - mae: 0.5072 - val_loss: 0.3712 - val_mae: 0.4988 - learning_rate: 0.0010
# Epoch 47/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3894 - mae: 0.5114 - val_loss: 0.3694 - val_mae: 0.4933 - learning_rate: 0.0010
# Epoch 48/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.3869 - mae: 0.5077 - val_loss: 0.3693 - val_mae: 0.4886 - learning_rate: 0.0010
# Epoch 49/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3867 - mae: 0.5076 - val_loss: 0.3682 - val_mae: 0.4922 - learning_rate: 0.0010
# Epoch 50/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3855 - mae: 0.5073 - val_loss: 0.3677 - val_mae: 0.4956 - learning_rate: 0.0010
# Epoch 51/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3823 - mae: 0.5052 - val_loss: 0.3665 - val_mae: 0.4937 - learning_rate: 0.0010
# Epoch 52/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3815 - mae: 0.5050 - val_loss: 0.3668 - val_mae: 0.4917 - learning_rate: 0.0010
# Epoch 53/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3771 - mae: 0.5005 - val_loss: 0.3657 - val_mae: 0.4953 - learning_rate: 0.0010
# Epoch 54/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3821 - mae: 0.5051 - val_loss: 0.3655 - val_mae: 0.4923 - learning_rate: 0.0010
# Epoch 55/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.3820 - mae: 0.5034 - val_loss: 0.3615 - val_mae: 0.4893 - learning_rate: 0.0010
# Epoch 56/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.3866 - mae: 0.5069 - val_loss: 0.3619 - val_mae: 0.4913 - learning_rate: 0.0010
# Epoch 57/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3720 - mae: 0.4950 - val_loss: 0.3619 - val_mae: 0.4922 - learning_rate: 0.0010
# Epoch 58/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.3794 - mae: 0.5020 - val_loss: 0.3634 - val_mae: 0.4876 - learning_rate: 0.0010
# Epoch 59/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3781 - mae: 0.5023 - val_loss: 0.3592 - val_mae: 0.4857 - learning_rate: 0.0010
# Epoch 60/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3735 - mae: 0.4963 - val_loss: 0.3598 - val_mae: 0.4891 - learning_rate: 0.0010
# Epoch 61/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3802 - mae: 0.5021 - val_loss: 0.3562 - val_mae: 0.4841 - learning_rate: 0.0010
# Epoch 62/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3741 - mae: 0.4983 - val_loss: 0.3551 - val_mae: 0.4820 - learning_rate: 0.0010
# Epoch 63/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3780 - mae: 0.5005 - val_loss: 0.3586 - val_mae: 0.4912 - learning_rate: 0.0010
# Epoch 64/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.3744 - mae: 0.4980 - val_loss: 0.3545 - val_mae: 0.4789 - learning_rate: 0.0010
# Epoch 65/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3690 - mae: 0.4923 - val_loss: 0.3538 - val_mae: 0.4839 - learning_rate: 0.0010
# Epoch 66/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3723 - mae: 0.4956 - val_loss: 0.3521 - val_mae: 0.4802 - learning_rate: 0.0010
# Epoch 67/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3691 - mae: 0.4924 - val_loss: 0.3502 - val_mae: 0.4745 - learning_rate: 0.0010
# Epoch 68/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.3754 - mae: 0.4961 - val_loss: 0.3496 - val_mae: 0.4787 - learning_rate: 0.0010
# Epoch 69/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3715 - mae: 0.4939 - val_loss: 0.3491 - val_mae: 0.4773 - learning_rate: 0.0010
# Epoch 70/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3715 - mae: 0.4938 - val_loss: 0.3484 - val_mae: 0.4750 - learning_rate: 0.0010
# Epoch 71/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3692 - mae: 0.4929 - val_loss: 0.3469 - val_mae: 0.4778 - learning_rate: 0.0010
# Epoch 72/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3656 - mae: 0.4889 - val_loss: 0.3484 - val_mae: 0.4829 - learning_rate: 0.0010
# Epoch 73/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3653 - mae: 0.4882 - val_loss: 0.3457 - val_mae: 0.4774 - learning_rate: 0.0010
# Epoch 74/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3659 - mae: 0.4896 - val_loss: 0.3439 - val_mae: 0.4700 - learning_rate: 0.0010
# Epoch 75/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3633 - mae: 0.4878 - val_loss: 0.3425 - val_mae: 0.4700 - learning_rate: 0.0010
# Epoch 76/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.3682 - mae: 0.4909 - val_loss: 0.3403 - val_mae: 0.4686 - learning_rate: 0.0010
# Epoch 77/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3649 - mae: 0.4879 - val_loss: 0.3436 - val_mae: 0.4756 - learning_rate: 0.0010
# Epoch 78/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3581 - mae: 0.4832 - val_loss: 0.3388 - val_mae: 0.4679 - learning_rate: 0.0010
# Epoch 79/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3625 - mae: 0.4866 - val_loss: 0.3384 - val_mae: 0.4627 - learning_rate: 0.0010
# Epoch 80/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3605 - mae: 0.4864 - val_loss: 0.3380 - val_mae: 0.4661 - learning_rate: 0.0010
# Epoch 81/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3647 - mae: 0.4887 - val_loss: 0.3367 - val_mae: 0.4621 - learning_rate: 0.0010
# Epoch 82/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3608 - mae: 0.4823 - val_loss: 0.3385 - val_mae: 0.4739 - learning_rate: 0.0010
# Epoch 83/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3630 - mae: 0.4870 - val_loss: 0.3345 - val_mae: 0.4656 - learning_rate: 0.0010
# Epoch 84/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3607 - mae: 0.4861 - val_loss: 0.3336 - val_mae: 0.4610 - learning_rate: 0.0010
# Epoch 85/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.3534 - mae: 0.4808 - val_loss: 0.3344 - val_mae: 0.4725 - learning_rate: 0.0010
# Epoch 86/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3609 - mae: 0.4866 - val_loss: 0.3313 - val_mae: 0.4625 - learning_rate: 0.0010
# Epoch 87/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3589 - mae: 0.4825 - val_loss: 0.3312 - val_mae: 0.4655 - learning_rate: 0.0010
# Epoch 88/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3558 - mae: 0.4827 - val_loss: 0.3297 - val_mae: 0.4589 - learning_rate: 0.0010
# Epoch 89/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.3575 - mae: 0.4809 - val_loss: 0.3302 - val_mae: 0.4630 - learning_rate: 0.0010
# Epoch 90/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3540 - mae: 0.4801 - val_loss: 0.3262 - val_mae: 0.4581 - learning_rate: 0.0010
# Epoch 91/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.3521 - mae: 0.4769 - val_loss: 0.3288 - val_mae: 0.4648 - learning_rate: 0.0010
# Epoch 92/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3535 - mae: 0.4793 - val_loss: 0.3253 - val_mae: 0.4589 - learning_rate: 0.0010
# Epoch 93/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.3505 - mae: 0.4772 - val_loss: 0.3272 - val_mae: 0.4658 - learning_rate: 0.0010
# Epoch 94/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3551 - mae: 0.4808 - val_loss: 0.3212 - val_mae: 0.4520 - learning_rate: 0.0010
# Epoch 95/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3527 - mae: 0.4777 - val_loss: 0.3212 - val_mae: 0.4526 - learning_rate: 0.0010
# Epoch 96/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3467 - mae: 0.4728 - val_loss: 0.3211 - val_mae: 0.4528 - learning_rate: 0.0010
# Epoch 97/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.3473 - mae: 0.4732 - val_loss: 0.3206 - val_mae: 0.4528 - learning_rate: 0.0010
# Epoch 98/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3484 - mae: 0.4731 - val_loss: 0.3251 - val_mae: 0.4666 - learning_rate: 0.0010
# Epoch 99/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3512 - mae: 0.4773 - val_loss: 0.3179 - val_mae: 0.4484 - learning_rate: 0.0010
# Epoch 100/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3454 - mae: 0.4701 - val_loss: 0.3165 - val_mae: 0.4501 - learning_rate: 0.0010
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │         1,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,649 (45.50 KB)
#  Trainable params: 11,649 (45.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 1.0394 - mae: 0.7858 - val_loss: 0.4082 - val_mae: 0.5314 - learning_rate: 0.0010
# Epoch 2/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4650 - mae: 0.5576 - val_loss: 0.3826 - val_mae: 0.5116 - learning_rate: 0.0010
# Epoch 3/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.4255 - mae: 0.5327 - val_loss: 0.3627 - val_mae: 0.4934 - learning_rate: 0.0010
# Epoch 4/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4150 - mae: 0.5255 - val_loss: 0.3706 - val_mae: 0.5011 - learning_rate: 0.0010
# Epoch 5/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3922 - mae: 0.5098 - val_loss: 0.3399 - val_mae: 0.4739 - learning_rate: 0.0010
# Epoch 6/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3779 - mae: 0.4986 - val_loss: 0.3381 - val_mae: 0.4758 - learning_rate: 0.0010
# Epoch 7/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.3732 - mae: 0.4957 - val_loss: 0.3237 - val_mae: 0.4635 - learning_rate: 0.0010
# Epoch 8/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3627 - mae: 0.4873 - val_loss: 0.3181 - val_mae: 0.4548 - learning_rate: 0.0010
# Epoch 9/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3523 - mae: 0.4758 - val_loss: 0.3144 - val_mae: 0.4507 - learning_rate: 0.0010
# Epoch 10/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3488 - mae: 0.4752 - val_loss: 0.3078 - val_mae: 0.4429 - learning_rate: 0.0010
# Epoch 11/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3395 - mae: 0.4652 - val_loss: 0.3098 - val_mae: 0.4460 - learning_rate: 0.0010
# Epoch 12/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.3372 - mae: 0.4658 - val_loss: 0.2960 - val_mae: 0.4348 - learning_rate: 0.0010
# Epoch 13/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3296 - mae: 0.4579 - val_loss: 0.2942 - val_mae: 0.4332 - learning_rate: 0.0010
# Epoch 14/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3261 - mae: 0.4539 - val_loss: 0.2927 - val_mae: 0.4309 - learning_rate: 0.0010
# Epoch 15/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.3232 - mae: 0.4527 - val_loss: 0.2854 - val_mae: 0.4296 - learning_rate: 0.0010
# Epoch 16/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3166 - mae: 0.4464 - val_loss: 0.2811 - val_mae: 0.4148 - learning_rate: 0.0010
# Epoch 17/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3272 - mae: 0.4525 - val_loss: 0.2835 - val_mae: 0.4181 - learning_rate: 0.0010
# Epoch 18/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3125 - mae: 0.4414 - val_loss: 0.2810 - val_mae: 0.4170 - learning_rate: 0.0010
# Epoch 19/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.3157 - mae: 0.4446 - val_loss: 0.2741 - val_mae: 0.4050 - learning_rate: 0.0010
# Epoch 20/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3119 - mae: 0.4400 - val_loss: 0.2763 - val_mae: 0.4176 - learning_rate: 0.0010
# Epoch 21/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3076 - mae: 0.4373 - val_loss: 0.2722 - val_mae: 0.4104 - learning_rate: 0.0010
# Epoch 22/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3071 - mae: 0.4358 - val_loss: 0.2696 - val_mae: 0.4069 - learning_rate: 0.0010
# Epoch 23/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.3065 - mae: 0.4350 - val_loss: 0.2666 - val_mae: 0.4018 - learning_rate: 0.0010
# Epoch 24/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3011 - mae: 0.4311 - val_loss: 0.2721 - val_mae: 0.4053 - learning_rate: 0.0010
# Epoch 25/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3032 - mae: 0.4332 - val_loss: 0.2693 - val_mae: 0.4031 - learning_rate: 0.0010
# Epoch 26/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2989 - mae: 0.4299 - val_loss: 0.2655 - val_mae: 0.4017 - learning_rate: 0.0010
# Epoch 27/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.3031 - mae: 0.4321 - val_loss: 0.2598 - val_mae: 0.3949 - learning_rate: 0.0010
# Epoch 28/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.3010 - mae: 0.4307 - val_loss: 0.2659 - val_mae: 0.3954 - learning_rate: 0.0010
# Epoch 29/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2984 - mae: 0.4293 - val_loss: 0.2626 - val_mae: 0.3994 - learning_rate: 0.0010
# Epoch 30/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2913 - mae: 0.4227 - val_loss: 0.2626 - val_mae: 0.3967 - learning_rate: 0.0010
# Epoch 31/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.2963 - mae: 0.4255 - val_loss: 0.2587 - val_mae: 0.3938 - learning_rate: 0.0010
# Epoch 32/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2900 - mae: 0.4200 - val_loss: 0.2632 - val_mae: 0.3974 - learning_rate: 0.0010
# Epoch 33/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2954 - mae: 0.4261 - val_loss: 0.2617 - val_mae: 0.3995 - learning_rate: 0.0010
# Epoch 34/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2884 - mae: 0.4192 - val_loss: 0.2567 - val_mae: 0.3872 - learning_rate: 0.0010
# Epoch 35/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.2894 - mae: 0.4202 - val_loss: 0.2550 - val_mae: 0.3873 - learning_rate: 0.0010
# Epoch 36/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2928 - mae: 0.4235 - val_loss: 0.2547 - val_mae: 0.3884 - learning_rate: 0.0010
# Epoch 37/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2880 - mae: 0.4202 - val_loss: 0.2592 - val_mae: 0.3966 - learning_rate: 0.0010
# Epoch 38/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2871 - mae: 0.4154 - val_loss: 0.2566 - val_mae: 0.3840 - learning_rate: 0.0010
# Epoch 39/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2918 - mae: 0.4194 - val_loss: 0.2539 - val_mae: 0.3918 - learning_rate: 0.0010
# Epoch 40/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2770 - mae: 0.4109 - val_loss: 0.2510 - val_mae: 0.3816 - learning_rate: 0.0010
# Epoch 41/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2796 - mae: 0.4120 - val_loss: 0.2551 - val_mae: 0.3909 - learning_rate: 0.0010
# Epoch 42/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2773 - mae: 0.4108 - val_loss: 0.2455 - val_mae: 0.3810 - learning_rate: 0.0010
# Epoch 43/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 0.2895 - mae: 0.4195 - val_loss: 0.2510 - val_mae: 0.3841 - learning_rate: 0.0010
# Epoch 44/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2790 - mae: 0.4104 - val_loss: 0.2507 - val_mae: 0.3809 - learning_rate: 0.0010
# Epoch 45/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2855 - mae: 0.4150 - val_loss: 0.2524 - val_mae: 0.3881 - learning_rate: 0.0010
# Epoch 46/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2842 - mae: 0.4153 - val_loss: 0.2492 - val_mae: 0.3785 - learning_rate: 0.0010
# Epoch 47/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.2789 - mae: 0.4102 - val_loss: 0.2464 - val_mae: 0.3720 - learning_rate: 0.0010
# Epoch 48/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2779 - mae: 0.4087 - val_loss: 0.2434 - val_mae: 0.3708 - learning_rate: 0.0010
# Epoch 49/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2784 - mae: 0.4092 - val_loss: 0.2478 - val_mae: 0.3819 - learning_rate: 0.0010
# Epoch 50/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2850 - mae: 0.4154 - val_loss: 0.2441 - val_mae: 0.3729 - learning_rate: 0.0010
# Epoch 51/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2797 - mae: 0.4092 - val_loss: 0.2453 - val_mae: 0.3793 - learning_rate: 0.0010
# Epoch 52/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2794 - mae: 0.4112 - val_loss: 0.2549 - val_mae: 0.3868 - learning_rate: 0.0010
# Epoch 53/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2876 - mae: 0.4164 - val_loss: 0.2458 - val_mae: 0.3768 - learning_rate: 0.0010
# Epoch 54/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2795 - mae: 0.4096 - val_loss: 0.2466 - val_mae: 0.3766 - learning_rate: 0.0010
# Epoch 55/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2811 - mae: 0.4107 - val_loss: 0.2485 - val_mae: 0.3832 - learning_rate: 0.0010
# Epoch 56/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.2773 - mae: 0.4080 - val_loss: 0.2412 - val_mae: 0.3698 - learning_rate: 0.0010
# Epoch 57/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2773 - mae: 0.4077 - val_loss: 0.2463 - val_mae: 0.3829 - learning_rate: 0.0010
# Epoch 58/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2705 - mae: 0.4028 - val_loss: 0.2402 - val_mae: 0.3688 - learning_rate: 0.0010
# Epoch 59/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2720 - mae: 0.4039 - val_loss: 0.2431 - val_mae: 0.3711 - learning_rate: 0.0010
# Epoch 60/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.2781 - mae: 0.4082 - val_loss: 0.2391 - val_mae: 0.3698 - learning_rate: 0.0010
# Epoch 61/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2740 - mae: 0.4051 - val_loss: 0.2415 - val_mae: 0.3778 - learning_rate: 0.0010
# Epoch 62/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2718 - mae: 0.4026 - val_loss: 0.2438 - val_mae: 0.3781 - learning_rate: 0.0010
# Epoch 63/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2727 - mae: 0.4041 - val_loss: 0.2411 - val_mae: 0.3749 - learning_rate: 0.0010
# Epoch 64/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.2701 - mae: 0.4019 - val_loss: 0.2445 - val_mae: 0.3736 - learning_rate: 0.0010
# Epoch 65/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2698 - mae: 0.4019 - val_loss: 0.2354 - val_mae: 0.3658 - learning_rate: 0.0010
# Epoch 66/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2706 - mae: 0.4037 - val_loss: 0.2396 - val_mae: 0.3734 - learning_rate: 0.0010
# Epoch 67/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2720 - mae: 0.4024 - val_loss: 0.2387 - val_mae: 0.3703 - learning_rate: 0.0010
# Epoch 68/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2749 - mae: 0.4045 - val_loss: 0.2361 - val_mae: 0.3679 - learning_rate: 0.0010
# Epoch 69/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2707 - mae: 0.4009 - val_loss: 0.2375 - val_mae: 0.3702 - learning_rate: 0.0010
# Epoch 70/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2692 - mae: 0.4001 - val_loss: 0.2356 - val_mae: 0.3631 - learning_rate: 0.0010
# Epoch 71/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2714 - mae: 0.4020 - val_loss: 0.2406 - val_mae: 0.3680 - learning_rate: 0.0010
# Epoch 72/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2710 - mae: 0.4010 - val_loss: 0.2357 - val_mae: 0.3633 - learning_rate: 0.0010
# Epoch 73/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.2712 - mae: 0.4018 - val_loss: 0.2331 - val_mae: 0.3609 - learning_rate: 0.0010
# Epoch 74/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2707 - mae: 0.4017 - val_loss: 0.2400 - val_mae: 0.3779 - learning_rate: 0.0010
# Epoch 75/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2707 - mae: 0.4024 - val_loss: 0.2361 - val_mae: 0.3701 - learning_rate: 0.0010
# Epoch 76/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2689 - mae: 0.4007 - val_loss: 0.2327 - val_mae: 0.3644 - learning_rate: 0.0010
# Epoch 77/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.2640 - mae: 0.3944 - val_loss: 0.2448 - val_mae: 0.3753 - learning_rate: 0.0010
# Epoch 78/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2714 - mae: 0.4010 - val_loss: 0.2393 - val_mae: 0.3682 - learning_rate: 0.0010
# Epoch 79/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2692 - mae: 0.3999 - val_loss: 0.2348 - val_mae: 0.3628 - learning_rate: 0.0010
# Epoch 80/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2748 - mae: 0.4029 - val_loss: 0.2347 - val_mae: 0.3707 - learning_rate: 0.0010
# Epoch 81/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.2657 - mae: 0.3965 - val_loss: 0.2331 - val_mae: 0.3642 - learning_rate: 0.0010
# Epoch 82/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2689 - mae: 0.3991 - val_loss: 0.2321 - val_mae: 0.3668 - learning_rate: 0.0010
# Epoch 83/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2663 - mae: 0.3978 - val_loss: 0.2336 - val_mae: 0.3670 - learning_rate: 0.0010
# Epoch 84/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2661 - mae: 0.3975 - val_loss: 0.2313 - val_mae: 0.3641 - learning_rate: 0.0010
# Epoch 85/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2700 - mae: 0.3989 - val_loss: 0.2346 - val_mae: 0.3636 - learning_rate: 0.0010
# Epoch 86/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2677 - mae: 0.3977 - val_loss: 0.2349 - val_mae: 0.3657 - learning_rate: 0.0010
# Epoch 87/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2674 - mae: 0.3970 - val_loss: 0.2357 - val_mae: 0.3651 - learning_rate: 0.0010
# Epoch 88/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2624 - mae: 0.3925 - val_loss: 0.2284 - val_mae: 0.3572 - learning_rate: 0.0010
# Epoch 89/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2629 - mae: 0.3933 - val_loss: 0.2315 - val_mae: 0.3584 - learning_rate: 0.0010
# Epoch 90/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.2689 - mae: 0.3997 - val_loss: 0.2396 - val_mae: 0.3716 - learning_rate: 0.0010
# Epoch 91/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2704 - mae: 0.3993 - val_loss: 0.2331 - val_mae: 0.3651 - learning_rate: 0.0010
# Epoch 92/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2658 - mae: 0.3980 - val_loss: 0.2388 - val_mae: 0.3699 - learning_rate: 0.0010
# Epoch 93/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2644 - mae: 0.3952 - val_loss: 0.2335 - val_mae: 0.3628 - learning_rate: 0.0010
# Epoch 94/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.2639 - mae: 0.3940 - val_loss: 0.2339 - val_mae: 0.3666 - learning_rate: 0.0010
# Epoch 95/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2609 - mae: 0.3916 - val_loss: 0.2365 - val_mae: 0.3704 - learning_rate: 0.0010
# Epoch 96/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2642 - mae: 0.3937 - val_loss: 0.2348 - val_mae: 0.3615 - learning_rate: 0.0010
# Epoch 97/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2615 - mae: 0.3927 - val_loss: 0.2329 - val_mae: 0.3545 - learning_rate: 0.0010
# Epoch 98/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.2636 - mae: 0.3940 - val_loss: 0.2384 - val_mae: 0.3712 - learning_rate: 0.0010
# Epoch 99/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2571 - mae: 0.3882 - val_loss: 0.2277 - val_mae: 0.3559 - learning_rate: 5.0000e-04
# Epoch 100/100
# 915/915 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2585 - mae: 0.3872 - val_loss: 0.2245 - val_mae: 0.3498 - learning_rate: 5.0000e-04
#
# БАЗОВАЯ МОДЕЛЬ:
# MSE: 18.0324
# MAE: 2.9301
# RMSE: 4.2465
# R² Score: 0.5208
#
# МОДЕЛЬ С RBM:
# MSE: 22.9499
# MAE: 3.5729
# RMSE: 4.7906
# R² Score: 0.3902
#
# УЛУЧШЕНИЕ RBM МОДЕЛИ ОТНОСИТЕЛЬНО БАЗОВОЙ:
# MSE: -27.27%
# MAE: -21.94%
# RMSE: -12.81%
# R²: -13.07%
